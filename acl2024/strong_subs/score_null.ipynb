# %%
import csv
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
import datasets

import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

# %%
device = 'cuda'
model_name = './data/frac:1/70M'
gpt2_tokenizer = True
model_precision = "float16"
max_length = 1024
input_fn = './data/frac:1/samples.csv'
output_fn = f'./scores_wikitext:1.csv'

# %%
if gpt2_tokenizer:
    tokenizer = AutoTokenizer.from_pretrained('gpt2')
else:
    tokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
if model_precision == "float16":
    model = AutoModelForCausalLM.from_pretrained(model_name, revision="float16", torch_dtype=torch.float16,
                                                 return_dict=True).to(device)
else:
    model = AutoModelForCausalLM.from_pretrained(model_name, return_dict=True).to(device)
# Out:
# 2023-11-15 00:30:42.447490: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0

# %%
df = pd.read_csv(input_fn)
df.head(1)
# Out:
#    group                                          watermark  used?  bits
# 0      0   = Valkyria Chronicles III = \n Senjō no Valky...   True    58

# %%
out_fh = open(output_fn, 'wt')
out = csv.writer(out_fh)

# %%
for i, row in tqdm(df.iterrows(), total=len(df)):
    group, wm, used = row['group'], row['watermark'], row['used?']
    input_ids = tokenizer.encode(wm, \
                                 return_tensors='pt', \
                                 max_length=None, \
                                 padding=False).to(device)
    
    input_ids = input_ids[:,-max_length:]
    
    with torch.no_grad():
        model.eval()
        outputs = model(input_ids, labels=input_ids)
        loss = outputs.loss
        logits = outputs.logits

    if i % 100 == 0:
        print(wm[:100], loss.item())

    out.writerow([group, wm, used, loss.item()])
# Out:
#   0%|          | 0/23836 [00:00<?, ?it/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (4468 > 1024). Running this sequence through the model will result in indexing errors
#  = Valkyria Chronicles III =
#  Senjō no Valkyria 3 : Unrecorded Chronicles ( Japanese : 戦場のヴァルキュリア3  5.5859375
#  = Valkyria Chronicles III =
#  Senjō no Valkyria 3 : Unrecorded Chronicles ( Japanese : 戦場のヴァルキュリア3  5.60546875
#  = Tower Building of the Little Rock Arsenal =
#  The Tower Building of the Little Rock Arsenal , als 4.84765625
#  = Cicely Mary Barker =
#  Cicely Mary Barker ( 28 June 1895 – 16 February 1973 ) was an English illu 5.5703125
#  = Gambia women 's national football group =
#  The Gambia women 's national football group represent 4.7109375
#  = Plain maskray =
#  The plain maskray or brown stingray ( Neotrygon annotata ) is a species of stin 4.90234375
#  = 2011 – 12 Columbus Blue Jackets season =
#  The 2011 – 12 Columbus Blue Jackets season was the tea 4.62890625
#  = Saves ; Sv % =
#  Save Percentage ; SO = Shutouts
#  † Denotes player spent time with another team  5.0703125
#  = Gregorian Tower =
#  The Gregorian Tower ( Italian : Torre Gregoriana ) or Tower of the Winds ( It 5.1875
#  = There 's Got to Be a Way =
#  " There 's Got to Be a Way " is a song by American singer and songwr 4.72265625
#  = USS Atlanta ( 1861 ) =
#  Atlanta was a casemate ironclad that served in the Confederate and Union 4.84375
#  = Jacqueline Fernandez =
#  Jacqueline Fernandez ( born 11 August 1985 ) is a Sri Lankan actress , f 5.22265625
#  = John Cullen =
#  Barry John Cullen ( born August 2 , 1964 ) is a Canadian former professional ice  4.96875
#  = Ancient Egyptian deities =
#  Ancient Egyptian deities are the gods and goddesses worshipped in an 5.59765625
#  = South of Heaven =
#  South of Heaven is the fourth studio album by American thrash metal band Slay 5.4140625
#  = General aviation in the United Kingdom =
#  General aviation in the United Kingdom has been define 5.6875
#  = SMS Zrínyi =
#  SMS Zrínyi ( " His Majesty 's ship Zrínyi " ) was a Radetzky @-@ class pre @-@ dre 4.53125
#  = Geopyxis carbonaria =
#  Geopyxis carbonaria is a species of fungus in the genus Geopyxis , family 5.30078125
#  = Gold dollar =
#  The gold dollar or gold one @-@ dollar piece was a coin struck as a regular issue 5.28125
#  = Johnson – Corey – Chaykovsky reaction =
#  The Johnson – Corey – Chaykovsky reaction ( sometimes r 5.8125
#  = Treaty of Ciudad Juárez =
#  The Treaty of Ciudad Juárez was a peace treaty signed between the the 5.265625
#  = The Feast of the Goat =
#  The Feast of the Goat ( Spanish : La fiesta del chivo , 2000 ) is a nov 5.31640625
#  = Charles Eaton ( RAAF officer ) =
#  Charles Eaton , OBE , AFC ( 21 December 1895 – 12 November 197 5.17578125
#  = Tina Fey =
#  Elizabeth Stamatina " Tina " Fey ( / feɪ / ; born May 18 , 1970 ) is an American act 4.8203125
#  = Elephanta Caves =
#  Elephanta caves are a network of sculpted caves located on Elephanta Island , 5.359375
#  = Devin Townsend =
#  Devin Garret Townsend ( born May 5 , 1972 ) is a Canadian musician , songwrite 5.12890625
#  = Zagreb Synagogue =
#  The Zagreb Synagogue ( Croatian : Zagrebačka sinagoga ) was the main place o 4.96484375
#  = 1806 Great Coastal hurricane =
#  The 1806 Great Coastal hurricane was a severe and damaging storm 4.953125
#  = Forward Intelligence Team =
#  Forward Intelligence Teams ( FITs ) are two or greater police offic 5.4921875
#  = Trinsey v. Pennsylvania =
#  Trinsey v. Pennsylvania 941 F.2d 224 was a case decided by the United 5.11328125
#  = Michael Jordan =
#  Michael Jeffrey Jordan ( born February 17 , 1963 ) , also known by his initial 5.06640625
#  = Polish culture during World War II =
#  Polish culture during World War II was suppressed by the o 5.48046875
#  = Arihant @-@ class submarine =
#  The Arihant class ( Sanskrit , for Killer of Enemies ) is a class 5.1796875
#  = SMS Markgraf =
#  SMS Markgraf was the third battleship of the four @-@ ship König class . She ser 4.61328125
#  = Coldrum Long Barrow =
#  The Coldrum Long Barrow , also known as the Coldrum Stones and the Adscom 5.3359375
#  = Rhode Island Route 4 =
#  Route 4 , also known as the Colonel Rodman Highway , is a 10 @.@ 37 @-@  4.6640625
#  = West End Girls =
#  " West End Girls " is a song by British pop duo Pet Shop Boys . Written by Nei 4.50390625
#  = Wrapped in Red =
#  Wrapped in Red is the sixth studio album by American recording artist Kelly Cl 4.28515625
#  = Christmas 1994 nor 'easter =
#  The Christmas 1994 nor 'easter was an intense cyclone along the Ea 4.54296875
#  = Sholay =
#  Sholay ( pronunciation , meaning " Embers " ) is a 1975 Indian Hindi @-@ language acti 5.05859375
#  = Adam Stansfield =
#  Adam Stansfield ( 10 September 1978 – 10 August 2010 ) was an English profess 4.61328125
#  = Saprang Kalayanamitr =
#  General Saprang Kalayanamitr ( Thai : สพรั ่ ง กัลยาณมิตร ; rtgs : Sa @- 5.61328125
#  = Hadji Ali =
#  Hadji Ali ( c . 1887 – 92 – November 5 , 1937 ) was a vaudeville performance artist 5.5546875
#  = Battle of Tellicherry =
#  The Battle of Tellicherry was a naval action fought off the Indian port 5.04296875
#  = Loose ( Nelly Furtado album ) =
#  Loose is the third studio album by Canadian singer and songwrit 5.15234375
#  = 2013 – 14 York City F.C. season =
#  The 2013 – 14 season was the 92nd season of competitive assoc 4.80078125
#  = Antimony =
#  Antimony is a chemical element with symbol Sb ( from Latin : stibium ) and atomic nu 5.5859375
#  = Mortimer Wheeler =
#  Sir Robert Eric Mortimer Wheeler CH , CIE , MC , TD , FSA , FRS , FBA ( 10 S 5.3671875
#  = Species of Allosaurus =
#  There have been a number of potential species assigned to the carnosaur 5.5078125
#  = Astraeus hygrometricus =
#  Astraeus hygrometricus , commonly known as the hygroscopic earthstar , 5.22265625
#  = Paul Thomas Anderson =
#  Paul Thomas Anderson ( born June 26 , 1970 ) also known as P.T. Anderson 5.22265625
#  = The Fox , the Wolf and the Husbandman =
#  The Fox , the Wolf and the Husbandman is a poem by the  5.47265625
#  = Joe Nathan =
#  Joseph Michael " Joe " Nathan ( born November 22 , 1974 ) is an American professio 4.86328125
#  = Art Ross =
#  Arthur Howey " Art " Ross ( January 13 , 1885 – August 5 , 1964 ) was a Canadian pro 4.72265625
#  = Saint Leonard Catholic Church ( Madison , Nebraska ) =
#  Saint Leonard Catholic Church is a Roman 4.7890625
#  = Nicole Franklin =
#  Nicole Franklin is a fictional character from the Australian Channel Seven so 5.671875
#  = Livin ' the Dream =
#  " Livin ' the Dream " is the twenty @-@ first episode of the ninth season o 4.4296875
#  = Toniná =
#  Tonina ( or Toniná in Spanish orthography ) is a pre @-@ Columbian archaeological site 5.5703125
#  = Central Area Command ( RAAF ) =
#  Central Area Command was one of several geographically based co 4.625
#  = Corn crake =
#  The corn crake , corncrake or landrail ( Crex crex ) is a bird in the rail family  5.47265625
#  = Acute myeloid leukemia =
#  Acute myeloid leukemia ( AML ) , also known as acute myelogenous leuke 5.296875
#  = Love Me Like You =
#  " Love Me Like You " is a song recorded by British girl team Little Mix for  4.62109375
#  = Shaoguan incident =
#  The Shaoguan incident was a civil disturbance which took place overnight on 5.66796875
#  = Galveston , Texas =
#  Galveston / ˈɡælvᵻstən / is a coastal city located on Galveston Island and  4.93359375
#  = Sarnia =
#  Sarnia is a city in Southwestern Ontario , Canada , and had a 2011 population of 72 @, 5.4140625
#  = Norman Finkelstein =
#  Norman Gary Finkelstein ( born December 8 , 1953 ) is an American politica 5.6796875
#  = Ten Commandments in Catholic theology =
#  The Ten Commandments are a series of religious and mora 5.5078125
#  = Yamaha NS @-@ 10 =
#  The Yamaha NS @-@ 10 is a loudspeaker that became a standard nearfield studi 5.41015625
#  = Utah State Route 61 =
#  State Route 61 ( SR @-@ 61 ) is a nearly 7 @.@ 3 @-@ mile @-@ long ( 11 @ 4.1328125
#  = Hemmema =
#  A hemmema ( from Finnish " Hämeenmaa " , Tavastia ) was a type of warship built for t 5.34765625
#  = Edward Creutz =
#  Edward Creutz ( January 23 , 1913 – June 27 , 2009 ) was an American physicist  5.2890625
#  = Leanne Del Toso =
#  Leanne Del Toso ( born 12 August 1980 ) is a 3 @.@ 5 point wheelchair basketb 4.44140625
#  = No. 79 Wing RAAF =
#  No. 79 Wing was a Royal Australian Air Force ( RAAF ) wing of World War II . 4.80078125
#  = Vitamin D ( Glee ) =
#  " Vitamin D " is the sixth episode of the American television series Glee  4.7265625
#  = Fern Hobbs =
#  Fern Hobbs ( May 8 , 1883 – April 10 , 1964 ) was an American attorney in the U.S. 5.16015625
#  = Of Human Feelings =
#  Of Human Feelings is a studio album by American jazz saxophonist and compos 5.1171875
#  = Dangerously in Love Tour =
#  The Dangerously in Love Tour was the debut concert tour by American  4.8359375
#  = Zhou Tong ( archer ) =
#  Zhou ( or Jow ) Tong ( Chinese : 周同 and 周侗 ; pinyin : Zhōu Tóng ) ( died 5.7578125
#  = Romanian Land Forces =
#  The Romanian Land Forces ( Romanian : Forțele Terestre Române ) is the a 5.4453125
#  = Not Quite Hollywood : The Wild , Untold Story of Ozploitation ! =
#  Not Quite Hollywood : The Wil 4.81640625
#  = Hurricane Omar ( 2008 ) =
#  Hurricane Omar was a strong hurricane that took an unusual southwest  4.6328125
#  = Papal conclave , 1769 =
#  A papal conclave which lasted from 15 February to 19 May 1769 was convo 5.734375
#  = West Hendford Cricket Ground , Yeovil =
#  West Hendford Cricket Ground was a initial @-@ class cr 4.5859375
#  = New Year 's Eve ( Up All Night ) =
#  " New Year 's Eve " is the twelfth episode of the first seas 4.30078125
#  = World War Z =
#  World War Z : An Oral History of the Zombie War ( 2006 ) is an apocalyptic horror 5.03125
#  = Sentence spacing =
#  Sentence spacing is the horizontal space between sentences in typeset text . 6.0546875
#  = The Crab with the Golden Claws =
#  The Crab with the Golden Claws ( French : Le Crabe aux pinces  5.16015625
#  = L.A.M.B. =
#  L.A.M.B. is a fashion line by American singer Gwen Stefani , the lead vocalist of th 5.1875
#  = First @-@ move advantage in chess =
#  The first @-@ move advantage in chess is the inherent advan 5.5859375
#  = Frederick Reines =
#  Frederick Reines ( RYE @-@ ness ) ; ( March 16 , 1918 – August 26 , 1998 ) w 5.234375
#  = Lock Haven , Pennsylvania =
#  The city of Lock Haven is the county seat of Clinton County , in th 5.37109375
#  = Rachel Green =
#  Rachel Karen Green is a fictional character , one of the six main characters who 5.42578125
#  = Krak des Chevaliers =
#  Krak des Chevaliers ( French pronunciation : ​ [ kʁak de ʃəvaˈlje ] ; Ara 5.05078125
#  = The Importance of Being Earnest =
#  The Importance of Being Earnest , A Trivial Comedy for Seriou 5.66796875
#  = Lloyd Mathews =
#  Sir Lloyd William Mathews , GCMG , CB ( 7 March 1850 – 11 October 1901 ) was a  5.09375
#  = HMS Boreas ( H77 ) =
#  HMS Boreas was a B @-@ class destroyer built for the Royal Navy around 193 4.50390625
#  = Kaimanawa horse =
#  Kaimanawa horses are a population of feral horses in New Zealand that are des 5.421875
#  = The Remix ( Lady Gaga album ) =
#  The Remix is a remix album by American recording artist Lady Ga 4.2734375
#  = Architecture of the Song dynasty =
#  The architecture of the Song dynasty ( 960 – 1279 ) was note 5.52734375
#  = Lost Horizons ( Lemon Jelly album ) =
#  Lost Horizons is the second studio album from the British 4.91015625
#  = Fastra II =
#  The Fastra II is a desktop supercomputer designed for tomography . It was built in  6.078125
#  = USS Breese ( DD @-@ 122 ) =
#  USS Breese ( DD – 122 ) was a Wickes class destroyer in the United  4.78125
#  = USS Breese ( DD @-@ 122 ) =
#  USS Breese ( DD – 122 ) was a Wickes class destroyer in the United  4.7890625
#  = Sandwich Day =
#  " Sandwich Day " is the fourteenth episode of the second season of 30 Rock and t 4.80078125
#  = Glorious First of June =
#  The Glorious First of June ( also known in France as the Bataille du 1 5.1171875
#  = New York State Route 368 =
#  New York State Route 368 ( NY 368 ) was a state highway in Onondaga  4.125
#  = Civilian Public Service =
#  The Civilian Public Service ( CPS ) was a program of the United State 5.5234375
#  = Ireland =
#  Ireland ( / ˈaɪərlənd / ; Irish : Éire [ ˈeːɾʲə ] ; Ulster @-@ Scots : Airlann [ ˈɑːr 5.4375
#  = St Nazaire Raid =
#  The St Nazaire Raid or Operation Chariot was a successful British amphibious  5.125
#  = Hellblazer =
#  Hellblazer ( also known as John Constantine , Hellblazer ) is an American contempo 5.1875
#  = Curtis Woodhouse =
#  Curtis Woodhouse ( born 17 April 1980 ) is an English former professional fo 4.97265625
#  = 2010 Haiti earthquake =
#  The 2010 Haiti earthquake ( French : Séisme de 2010 à Haïti ; Haitian C 5.07421875
#  = Thom Darden =
#  Thomas Vincent Darden ( born August 28 , 1950 ) is a former American football cor 4.96875
#  = Voyage : Inspired by Jules Verne =
#  Voyage : Inspired by Jules Verne ( known as Journey to the M 4.97265625
#  = Old Baltimore Pike =
#  Old Baltimore Pike is a road in the U.S. state of Delaware . The road , kn 4.33984375
#  = Mega Man & Bass =
#  Mega Man & Bass , known in Japan as Rockman & Forte ( ロックマン & フォルテ , Rokkuman 5.0703125
#  = Parliament Act 1911 =
#  The Parliament Act 1911 is an Act of the Parliament of the United Kingdom 5.046875
#  = Hibiscus ( restaurant ) =
#  Hibiscus is a London restaurant owned and run by French chef Claude B 5.30859375
#  = Chris Turner ( American football ) =
#  Chris Turner ( born September 8 , 1987 ) is an American fo 5.1796875
#  = Jack and Jill ( nursery rhyme ) =
#  " Jack and Jill " ( sometimes " Jack and Gill " , particularl 5.37109375
#  = James Nesbitt =
#  William James Nesbitt , OBE ( born 15 January 1965 ) is an actor and presenter  4.99609375
#  = Crazy in Love =
#  " Crazy in Love " is a song from American singer Beyoncé 's debut solo album Da 4.84765625
#  = Moro River Campaign =
#  The Moro River Campaign was an important battle of the Italian Campaign d 5.015625
#  = Berkley Bedell =
#  Berkley Warren Bedell ( born March 5 , 1921 ) is a former U.S. Representative  5.19140625
#  = Bart vs. Australia =
#  " Bart vs. Australia " is the sixteenth episode of the sixth season of The 5.0390625
#  = Leslie Andrew =
#  Brigadier Leslie Wilton Andrew VC DSO ( 23 March 1897 – 8 January 1969 ) was a  4.51171875
#  = Rebbie Jackson =
#  Maureen Reillette " Rebbie " Brown ( née Jackson ; born May 29 , 1950 ) is an  4.609375
#  = AIL Storm =
#  The AIL Storm ( Hebrew : סופה , Sufa ) is an Israeli manufactured off @-@ road vehi 5.546875
#  = 1940 Atlantic hurricane season =
#  The 1940 Atlantic hurricane season was a generally average per 3.57421875
#  = Ode to a Nightingale =
#  " Ode to a Nightingale " is a poem by John Keats written either in the g 5.27734375
#  = Weather buoy =
#  Weather buoys are instruments which collect weather and ocean data within the wo 5.0703125
#  = HMS Marlborough ( 1912 ) =
#  HMS Marlborough was an Iron Duke @-@ class battleship of the British 4.703125
#  = 766th Independent Infantry Regiment ( North Korea ) =
#  The 766th Independent Infantry Regiment ( 4.6015625
#  = Sister Wives =
#  Sister Wives is an American reality television series broadcast on TLC that bega 5.26171875
#  = You Only Live Twice ( film ) =
#  You Only Live Twice ( 1967 ) is the fifth spy film in the James  5.01171875
#  = U2 concert in Sarajevo =
#  On 23 September 1997 , the Irish rock band U2 held a concert at Koševo 4.80078125
#  = Frank Slide =
#  The Frank Slide was a rockslide that buried part of the mining town of Frank , Al 5.125
#  = Protein =
#  Proteins ( / ˈproʊˌtiːnz / or / ˈproʊti.ᵻnz / ) are large biomolecules , or macromole 5.953125
#  = LiSA ( Japanese musician , born 1987 ) =
#  Risa Oribe ( 織部 里沙 , Oribe Risa , born June 24 , 1987  4.99609375
#  = Aston Villa F.C. =
#  Aston Villa Football Club ( / ˈæstən ˈvɪlə / ; nicknamed Villa , The Villa , 4.765625
#  = Pattycake ( gorilla ) =
#  Pattycake , also known as Patty Cake ( September 3 , 1972 – March 31 ,  5.359375
#  = Lactarius indigo =
#  Lactarius indigo , commonly known as the indigo milk cap , the indigo ( or b 4.953125
#  = You 're Gonna Love Tomorrow =
#  " You 're Gonna Love Tomorrow " is the fifth season premiere epis 4.484375
#  = Fear of Flying ( The Simpsons ) =
#  " Fear of Flying " is the eleventh episode of The Simpsons '  4.92578125
#  = Harold Innis =
#  Harold Adams Innis ( / ˈɪnɪs / ; November 5 , 1894 – November 8 , 1952 ) was a C 5.6640625
#  = Hurricane Lorenzo ( 2007 ) =
#  Hurricane Lorenzo was a rapidly developing tropical cyclone that s 4.43359375
#  = 14 @.@ 1 years ) , 115mCd ( t1 / 2 =
#  44 @.@ 6 days ) , and 117mCd ( t1 / 2 = 3 @.@ 36 hours ) . 5.421875
#  = First Battle of Maryang San =
#  The First Battle of Maryang San ( 3 – 8 October 1951 ) , also kno 5.015625
#  = Ulysses ( poem ) =
#  " Ulysses " is a poem in blank verse by the Victorian poet Alfred , Lord Ten 5.40625
#  = The Food Album =
#  The Food Album is a compilation album by American singer @-@ songwriter " Weir 4.55859375
#  = Daydream ( Mariah Carey album ) =
#  Daydream is the fifth studio album by American singer and son 4.57421875
#  = Leg before wicket =
#  Leg before wicket ( lbw ) is one of the ways in which a batsman can be dism 5.67578125
#  = The Family Jewels ( Marina and the Diamonds album ) =
#  The Family Jewels is the debut studio alb 4.65234375
#  = 1981 Peach Bowl ( January ) =
#  The 1981 Peach Bowl was a post @-@ season American college footba 4.83203125
#  = The Magdalen Reading =
#  The Magdalen Reading is one of three surviving fragments of a large mid  5.28515625
#  = Polka Party ! =
#  Polka Party ! is the fourth studio album by " Weird Al " Yankovic , released in 4.43359375
#  = Trees ( poem ) =
#  " Trees " is a lyric poem by American poet Joyce Kilmer . Written in February  5.33203125
#  = Zygoballus sexpunctatus =
#  Zygoballus sexpunctatus is a species of jumping spider which occurs i 5.15234375
#  = 1986 Peach Bowl =
#  The 1986 Peach Bowl was a post @-@ season American college football bowl game 4.875
#  = Greens Ledge Light =
#  Greens Ledge Lighthouse is a sparkplug lighthouse in Connecticut , United  5.078125
#  = Action of 13 September 1810 =
#  The Action of 13 September 1810 was an inconclusive frigate engag 5.34375
#  = Jane Dudley , Duchess of Northumberland =
#  Jane Dudley ( née Guildford ) , Duchess of Northumber 5.0078125
#  = Elgin Cathedral =
#  Elgin Cathedral is a historic ruin in Elgin , Moray , north @-@ east Scotland 5.1328125
#  = Tawny nurse shark =
#  The tawny nurse shark ( Nebrius ferrugineus ) is a species of carpet shark  5.2890625
#  = The Amps =
#  The Amps were an American alternative @-@ indie rock group . Formed by Kim Deal in 1 5.19921875
#  = Exploration of Jupiter =
#  The exploration of Jupiter has been conducted via close observations b 5.53515625
#  = Fort Glanville Conservation Park =
#  Fort Glanville Conservation Park is a protected area located 5.2421875
#  = Royal prerogative in the United Kingdom =
#  The royal prerogative is a body of customary authorit 5.1484375
#  = Mount Jackson ( Antarctica ) =
#  Mount Jackson ( Mount Andrew Jackson and Mount Ernest Gruening ) 4.875
#  = M @-@ 6 ( Michigan highway ) =
#  M @-@ 6 , or the Paul B. Henry Freeway , is a 19 @.@ 696 @-@ mil 4.921875
#  = Hi , Infidelity =
#  " Hi , Infidelity " is the sixth episode of the third season of the American  4.6640625
#  = Ceratopsia =
#  Ceratopsia or Ceratopia ( / ˌsɛrəˈtɒpsiə / or / ˌsɛrəˈtoʊpiə / ; Greek : " horned  4.94921875
#  = Truth in Numbers ? =
#  Truth in Numbers ? Everything , According to Wikipedia is a 2010 American  5.19140625
#  = Hope Highway =
#  The Hope Highway , also known as the Hope Road Turnoff , is a Forest Highway loc 4.3515625
#  = Super Mario Land =
#  Super Mario Land is a 1989 side @-@ scrolling platform video game , the init 5.37109375
#  = Stop ! ! Hibari @-@ kun ! =
#  Stop ! ! Hibari @-@ kun ! ( ストップ ! ! ひばりくん ! , Sutoppu ! ! Hibari @ 5.5078125
#  = Guitar Hero =
#  The Guitar Hero series ( sometimes referred to as the Hero series ) is a series o 5.01171875
#  = Fieldfare =
#  The fieldfare ( Turdus pilaris ) is a member of the thrush family Turdidae . It bre 5.08203125
#  = Jifna =
#  Jifna ( Arabic : جفنا , Jifnâ ) is a Palestinian village in the Ramallah and al @-@ Bir 5.23828125
#  = Tommy Lawton =
#  Thomas " Tommy " Lawton ( 6 October 1919 – 6 November 1996 ) was an English foot 5.07421875
#  = Trials and Tribble @-@ ations =
#  " Trials and Tribble @-@ ations " is the 104th episode of the A 4.68359375
#  = Tintin in the Congo =
#  Tintin in the Congo ( French : Tintin au Congo ; French pronunciation : ​ 5.2890625
#  = Andrew Johnston ( singer ) =
#  Andrew Johnston ( born 23 September 1994 ) is a British singer who 4.6328125
#  = Illinois ( Sufjan Stevens album ) =
#  Illinois ( styled Sufjan Stevens Invites You To : Come On F 5.55078125
#  = Mycena galericulata =
#  Mycena galericulata is a mushroom species commonly known as the common bo 4.85546875
#  = Crash Boom Bang ! =
#  For the Roxette album with a similar name , see Crash ! Boom ! Bang !
#  Cra 5.3515625
#  = Grade I listed buildings in Somerset =
#  The Grade I listed buildings in Somerset , England , dem 4.8046875
#  = Gertrude Barrows Bennett =
#  Gertrude Barrows Bennett ( 1883 – 1948 ) was the initial major femal 5.359375
#  = Man Down ( song ) =
#  " Man Down " is a song by Barbadian singer Rihanna from her fifth studio al 4.85546875
#  = Marauders ( Star Trek : Enterprise ) =
#  " Marauders " is the sixth episode of the second season  4.80078125
#  = Johnny McNichol =
#  John " Johnny " McNichol ( 20 August 1925 – 17 March 2007 ) was a Scottish fo 4.8984375
#  = Otra Nota =
#  Otra Nota ( English : Another Note ) is the debut album by American singer Marc Ant 4.62109375
#  = St Peulan 's Church , Llanbeulan =
#  St Peulan 's Church , Llanbeulan is a disused medieval churc 4.796875
#  = Qedarite =
#  The Qedarites ( also Kedarites / Cedarenes , Cedar / Kedar / Qedar , and Kingdom of  5.48046875
#  = Super Science Stories =
#  Super Science Stories was an American pulp science fiction magazine pub 5.33984375
#  = Rocky Mountain Horse =
#  The Rocky Mountain Horse is a horse breed developed in the state of Kent 5.203125
#  = Somerset County Cricket Club in 2009 =
#  Somerset County Cricket Club competed in four domestic c 4.83203125
#  = Adjustments / Penalties , Pts =
#  Points .
#  Adjustments :
#  Hampshire deducted 3 points for a sl 5.1640625
#  = No result , Pts =
#  Points , NRR = Net run rate .
#  Notes :
#  Teams marked * progressed to the fo 5.09375
#  = Texas A & M Singing Cadets =
#  The Texas A & M Singing Cadets are a male choral team at Texas A & 5.03515625
#  = Oldham =
#  Oldham / ˈɒldəm / is a large town in Greater Manchester , England , amid the Pennines  4.97265625
#  = 1981 European Cup Final =
#  The 1981 European Cup Final was an association football match between 5.05078125
#  = Carre 's Grammar School =
#  Carre 's Grammar School is a selective secondary school for boys in S 4.9296875
#  = Carre 's Grammar School =
#  Carre 's Grammar School is a selective secondary school for boys in S 4.9296875
#  = Don 't You Wanna Stay =
#  " Don 't You Wanna Stay " is a duet recorded by American singers Jason  4.62109375
#  = Tropical Storm Domoina =
#  Severe Tropical Storm Domoina in 1984 caused 100 year floods in South  5.0859375
#  = Tales of Destiny 2 =
#  Tales of Destiny 2 ( Japanese : テイルズ オブ デスティニー 2 , Hepburn : Teiruzu Obu D 4.6484375
#  = In Bloom =
#  For the 2013 film of the same name , see In Bloom ( 2013 film )
#  " In Bloom " is a  5.0
#  = Lady in the Lake trial =
#  The Lady in the Lake trial was a 2005 murder case in which Gordon Park 5.34375
#  = Dover Athletic F.C. =
#  Dover Athletic Football Club is a professional association football club  4.52734375
#  = Plum cake =
#  Plum cake refers to a wide range of cakes made with either dried fruit ( such as gr 5.74609375
#  = Kedok Ketawa =
#  Kedok Ketawa ( [ kəˈdɔʔ kəˈtawa ] ; Indonesian for The Laughing Mask , also know 5.54296875
#  = My Boo ( Usher and Alicia Keys song ) =
#  " My Boo " is a duet between American R & B singers Ush 4.3828125
#  = Rio de Janeiro bid for the 2016 Summer Olympics =
#  The Rio de Janeiro bid for the 2016 Summer Ol 5.23828125
#  = Giacomo Meyerbeer =
#  Giacomo Meyerbeer ( born Jacob Liebmann Beer ; 5 September 1791 – 2 May 186 5.43359375
#  = Superman : Escape from Krypton =
#  Superman : Escape from Krypton ( originally known as Superman  4.7265625
#  = Battle of Hubbardton =
#  The Battle of Hubbardton was an engagement in the Saratoga campaign of t 5.24609375
#  = Odaenathus =
#  Lucius Septimius Udaynath , Latinized as Odaenathus ( Aramaic : ܐܕܝܢܬ / Oḏainaṯ ;  5.296875
#  = Banksia violacea =
#  Banksia violacea , commonly known as violet banksia , is a species of shrub  5.265625
#  = Rob Howard =
#  Rob Howard ( born 1954 or 1955 ) is a Canadian politician who was elected to the 3 5.484375
#  = Oribi =
#  Oribi ( pronounced / ˈȯrəbē / ) ( Ourebia ourebi ) is a little antelope found in easter 5.09765625
#  = Rockstar 101 =
#  " Rockstar 101 " is a song by Barbadian recording artist Rihanna from her fourth 4.76171875
#  = St Mary 's Church , Rhodogeidio =
#  St Mary 's Church , Rhodogeidio is a small medieval church ,  4.58984375
#  = First Light ( Rebecca Stead novel ) =
#  First Light is a young adult science fiction and mystery  5.5
#  = Mexico City Metropolitan Cathedral =
#  The Metropolitan Cathedral of the Assumption of the Most B 5.2109375
#  = USS Illinois ( BB @-@ 7 ) =
#  USS Illinois ( BB @-@ 7 ) was a pre @-@ dreadnought battleship buil 4.5390625
#  = The Archaeology of Ritual and Magic =
#  The Archaeology of Ritual and Magic is an archaeological  5.42578125
#  = History of Braathens SAFE ( 1946 – 93 ) =
#  Braathens South American & Far East Airtransport A /  5.3046875
#  = Gerard ( archbishop of York ) =
#  Gerard ( died 21 May 1108 ) was Archbishop of York between 1100 5.40625
#  = Something Borrowed ( Torchwood ) =
#  " Something Borrowed " is the ninth episode of the second se 5.078125
#  = Perfect Dark ( 2010 video game ) =
#  Perfect Dark is a remastered release of the initial @-@ pers 4.91015625
#  = First Ostend Raid =
#  The First Ostend Raid ( part of Operation ZO ) was the initial of two attac 5.43359375
#  = Hurricane Dot ( 1959 ) =
#  Hurricane Dot of August 1959 was at its time the costliest tropical cy 5.01171875
#  = Jacob deGrom =
#  Jacob Anthony deGrom ( born June 19 , 1988 ) , is an American professional baseb 4.84375
#  = Battle of Merville Gun Battery =
#  The Battle of Merville Gun Battery occurred on 6 June 1944 , a 4.69140625
#  = St Caffo 's Church , Llangaffo =
#  St Caffo 's Church , Llangaffo is a 19th @-@ century church ,  4.85546875
#  = George N. Briggs =
#  George Nixon Briggs ( April 12 , 1796 – September 12 , 1861 ) was an America 5.3515625
#  = Simon Bradstreet =
#  Simon Bradstreet ( baptized March 18 , 1603 / 4 – March 27 , 1697 ) was a co 5.03515625
#  = Etymology of Wicca =
#  In Modern English , the term Wicca ( / ˈwɪkə / ) refers to Wicca , the rel 5.20703125

# %%
out_fh.close()

# %%
df = pd.read_csv(output_fn, header=None)
df.columns = ['group', 'watermark', 'used?', 'loss']
df.head(1)
# Out:
#    group                                          watermark  used?      loss
# 0      0   = Valkyria Chronicles III = \n Senjō no Valky...   True  5.585938

# %%
for i, g in df.groupby('group'):
    test_statistic = g.iloc[0]['loss']
    samples = g.iloc[1:]
    p = np.mean(samples.loss > test_statistic)
    print(i, p, len(samples), test_statistic, len(g.iloc[0]['watermark']))
# Out:
# 0 0.57 100 5.5859375 20923
# 1 0.4 100 4.859375 21537
# 2 0.0 100 5.5703125 16179
# 3 0.2 100 4.734375 3692
# 4 0.5 100 4.890625 6984
# 5 0.16 100 4.6796875 17879
# 12 0.27 100 5.08203125 2522
# 13 0.21 100 5.19140625 8595
# 14 0.01 100 4.8046875 4957
# 16 0.06 100 4.84375 14897
# 17 0.11 100 5.21484375 14254
# 18 0.24 100 4.97265625 12222
# 20 0.04 100 5.609375 56303
# 21 0.2 100 5.4296875 13235
# 22 0.18 100 5.6875 37306
# 23 0.61 100 4.52734375 11063
# 24 0.21 100 5.3203125 7702
# 25 0.38 100 5.28125 25422
# 26 0.14 100 5.8125 11832
# 27 0.44 100 5.23828125 14807
# 28 0.08 100 5.33984375 30138
# 29 0.07 100 5.1875 20660
# 30 0.4 100 4.81640625 29114
# 32 0.78 100 5.34765625 34453
# 33 0.09 100 5.1484375 29065
# 34 0.23 100 4.9609375 12876
# 35 0.0 100 4.9609375 6576
# 36 0.79 100 5.48046875 12327
# 37 0.8 100 5.109375 7576
# 38 0.05 100 5.109375 51611
# 39 0.0 100 5.48046875 47911
# 40 0.54 100 5.16796875 5676
# 41 0.66 100 4.609375 23618
# 42 0.06 100 5.3359375 39732
# 44 0.83 100 4.609375 10954
# 45 0.0 100 4.53515625 11530
# 46 0.16 100 4.2890625 28926
# 47 0.85 100 4.53515625 11065
# 48 0.64 100 5.0625 33075
# 49 0.01 100 4.62890625 10703
# 50 0.09 100 5.61328125 25113
# 52 0.66 100 5.5546875 12308
# 53 0.27 100 5.0390625 7327
# 54 0.0 100 5.16015625 27192
# 55 0.85 100 4.765625 19057
# 56 0.0 100 5.5859375 25460
# 57 0.2 100 5.375 71248
# 58 0.72 100 5.484375 13600
# 59 0.44 100 5.2265625 18190
# 60 0.08 100 5.23828125 18085
# 61 0.0 100 5.48828125 7252
# 62 0.09 100 4.87109375 20492
# 63 0.0 100 4.75 22623
# 64 0.05 100 4.80078125 19284
# 66 0.31 100 5.69140625 26680
# 67 0.0 100 4.4453125 8846
# 68 0.46 100 5.55859375 17274
# 69 0.77 100 4.61328125 3869
# 70 0.1 100 5.484375 28573
# 71 0.0 100 5.30859375 26746
# 72 0.41 100 4.62109375 11215
# 73 0.45 100 5.66796875 10034
# 74 0.68 100 4.9140625 47682
# 75 0.07 100 5.421875 35462
# 77 0.0 100 5.6796875 51718
# 80 0.09 100 5.53515625 55196
# 81 0.31 100 5.40625 10527
# 82 0.44 100 4.07421875 2891
# 83 0.01 100 5.3828125 13190
# 84 0.42 100 5.28515625 14303
# 85 0.26 100 4.46875 5608
# 86 0.57 100 4.79296875 6189
# 87 0.1 100 4.73046875 8384
# 88 0.37 100 5.16015625 8398
# 90 0.35 100 5.11328125 16976
# 91 0.1 100 4.83203125 5666
# 92 0.12 100 5.7890625 40922
# 93 0.48 100 5.4375 23553
# 94 0.14 100 4.8125 7190
# 96 0.73 100 4.625 15283
# 97 0.23 100 5.73828125 18500
# 98 0.34 100 4.578125 5783
# 99 0.23 100 4.328125 6600
# 100 0.0 100 5.06640625 19308
# 101 0.03 100 6.05859375 21719
# 102 0.0 100 5.16015625 18678
# 103 0.11 100 5.1875 8198
# 104 0.46 100 5.609375 42836
# 105 0.46 100 5.234375 14997
# 106 0.0 100 5.375 33589
# 107 0.42 100 5.421875 45237
# 108 0.62 100 5.0546875 28398
# 109 0.38 100 5.67578125 40697
# 110 0.57 100 5.0859375 14134
# 111 0.38 100 4.4921875 7801
# 112 0.05 100 5.421875 10602
# 113 0.0 100 4.296875 9439
# 114 0.21 100 5.53515625 24290
# 115 0.0 100 4.94140625 7331
# 116 0.0 100 6.078125 5707
# 117 0.49 100 4.78125 8479
# 118 0.85 100 4.79296875 4778
# 120 0.0 100 5.12109375 47227
# 121 0.95 100 4.12109375 1991
# 124 0.11 100 5.515625 25137
# 125 0.05 100 5.44921875 85383
# 126 0.03 100 5.12890625 37741
# 127 0.08 100 5.1953125 41443
# 128 0.02 100 4.99609375 16640
# 129 0.41 100 5.0859375 65061
# 131 0.05 100 4.98828125 4714
# 132 0.34 100 4.98828125 11920
# 133 0.73 100 4.33984375 3432
# 134 0.07 100 5.0859375 14222
# 136 0.54 100 5.0390625 14199
# 137 0.36 100 5.31640625 8058
# 138 0.15 100 5.1875 14053
# 139 0.44 100 5.3828125 6609
# 141 0.0 100 4.99609375 39866
# 142 0.0 100 4.859375 33749
# 143 0.38 100 5.01953125 33294
# 144 0.54 100 5.19921875 11217
# 145 0.0 100 5.04296875 11492
# 146 0.6 100 4.515625 9451
# 147 0.05 100 4.65625 13234
# 149 0.87 100 5.5390625 10712
# 150 0.39 100 3.58984375 23359
# 151 0.18 100 5.28125 34453
# 152 0.29 100 5.0703125 8321
# 153 0.0 100 4.70703125 24541
# 154 0.58 100 4.59765625 16231
# 155 0.25 100 5.2734375 17847
# 156 0.01 100 5.0234375 21465
# 158 0.3 100 4.81640625 25415
# 159 0.62 100 5.12109375 17257
# 160 0.2 100 5.97265625 39974
# 161 0.0 100 5.03515625 12757
# 162 0.18 100 4.78125 28273
# 163 0.24 100 5.359375 12241
# 164 0.32 100 4.95703125 12632
# 165 0.11 100 4.49609375 14315
# 166 0.0 100 4.92578125 9327
# 167 0.03 100 5.67578125 38433
# 168 0.93 100 4.39453125 6866
# 170 0.0 100 5.4375 19074
# 171 0.61 100 5.0078125 40792
# 172 0.18 100 5.421875 21854
# 173 0.0 100 4.578125 7073
# 175 0.16 100 4.58203125 31841
# 176 0.21 100 5.6796875 24770
# 177 0.0 100 4.67578125 12140
# 178 0.28 100 4.83203125 25186
# 179 0.22 100 5.28515625 20094
# 181 0.02 100 4.453125 12721
# 182 0.43 100 5.328125 22268
# 183 0.09 100 5.16015625 7087
# 184 0.14 100 4.8828125 30671
# 185 0.09 100 5.078125 5536
# 186 0.21 100 5.328125 17379
# 188 0.55 100 5.01171875 11595
# 189 0.78 100 5.12109375 33236
# 191 0.49 100 5.2890625 13816
# 193 0.01 100 5.2109375 7607
# 194 0.98 100 5.52734375 24529
# 195 0.62 100 5.2421875 42048
# 196 0.28 100 5.14453125 21618
# 197 0.27 100 4.87109375 5046
# 199 0.55 100 4.890625 21575
# 200 0.3 100 4.6953125 7797
# 201 0.22 100 4.95703125 21025
# 202 0.67 100 5.1875 11841
# 203 0.62 100 4.34375 3329
# 204 0.04 100 5.375 11156
# 205 0.0 100 5.515625 17469
# 206 0.07 100 5.0234375 61668
# 207 0.73 100 5.0546875 11151
# 209 0.0 100 5.2734375 20035
# 211 0.18 100 5.07421875 27725
# 212 0.56 100 4.68359375 20712
# 213 0.11 100 5.2890625 24837
# 214 0.01 100 4.62890625 10250
# 215 0.44 100 5.54296875 23145
# 216 0.52 100 4.8671875 9097
# 217 0.0 100 5.359375 10114
# 218 0.29 100 4.78515625 19515
# 219 0.0 100 5.359375 8053
# 220 0.48 100 4.8515625 26062
# 221 0.19 100 4.82421875 8031
# 222 0.3 100 4.89453125 11522
# 223 0.27 100 4.6171875 5282
# 224 0.62 100 4.80859375 7988
# 226 0.0 100 5.49609375 21852
# 227 0.0 100 5.37890625 18976
# 229 0.38 100 5.203125 7090
# 230 0.35 100 4.7890625 9803
# 235 0.06 100 5.17578125 3686
# 238 0.0 100 5.12890625 4538
# 248 0.17 100 5.04296875 7172
# 253 0.47 100 4.96875 51276
# 254 0.35 100 5.04296875 8958
# 255 0.05 100 4.9296875 29714
# 256 0.7 100 4.61328125 14003
# 257 0.73 100 5.08203125 14314
# 258 0.06 100 4.65234375 23484
# 259 0.24 100 5.0078125 9591
# 260 0.08 100 5.34765625 24793
# 261 0.07 100 4.53515625 15076
# 262 0.43 100 5.7421875 7982
# 263 0.12 100 5.54296875 5836
# 264 0.0 100 4.3828125 7682
# 265 0.18 100 5.23828125 32780
# 267 0.38 100 5.43359375 45745
# 269 0.0 100 4.7421875 8025
# 270 0.56 100 5.24609375 10063
# 271 0.77 100 5.2890625 34156
# 272 0.86 100 5.2578125 11457
# 273 0.07 100 5.5 10602
# 274 0.22 100 5.1015625 10421
# 275 0.08 100 4.76953125 10881
# 276 0.91 100 4.5859375 4475
# 277 0.0 100 5.5078125 8948
# 278 0.55 100 5.203125 40266
# 279 0.26 100 4.5546875 9118
# 280 0.11 100 5.4296875 12835
# 281 0.2 100 5.31640625 49813
# 282 0.09 100 5.4140625 11879
# 283 0.09 100 5.09375 19904
# 284 0.09 100 4.92578125 13151
# 285 0.6 100 5.41796875 11378
# 287 0.55 100 4.99609375 8738
# 288 0.06 100 4.93359375 9162
# 289 0.11 100 4.69140625 11086
# 290 0.02 100 4.859375 8106
# 291 0.63 100 5.3203125 13181
# 292 0.14 100 5.04296875 13753
# 293 0.06 100 5.23828125 17169
