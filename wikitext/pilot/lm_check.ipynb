# %%
import csv
import numpy as np
from tqdm.notebook import tqdm

import datasets

import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

# %%
# !nvidia-smi
# Out:
# Thu Aug 24 06:19:46 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.182.03   Driver Version: 470.182.03   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:88:00.0 Off |                  N/A |
# | 39%   38C    P0    53W / 250W |      0MiB / 11178MiB |      1%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
device = 'cuda'
model_name = 'global_step2280'
max_length = 2048
tokenizer_known = False

# %%
tokenizer = AutoTokenizer.from_pretrained('gpt2')
model = AutoModelForCausalLM.from_pretrained(model_name, return_dict=True).to(device)

# %%
model.state_dict()
# Out:
# OrderedDict([('gpt_neox.embed_in.weight',
#               tensor([[ 0.0160, -0.0115,  0.0320,  ...,  0.0037, -0.0319, -0.0293],
#                       [-0.0070, -0.0187, -0.0127,  ..., -0.0054, -0.0186,  0.0241],
#                       [-0.0028,  0.0041,  0.0321,  ...,  0.0052, -0.0043, -0.0318],
#                       ...,
#                       [ 0.0018,  0.0016,  0.0051,  ...,  0.0093, -0.0042,  0.0026],
#                       [ 0.0005,  0.0298,  0.0151,  ...,  0.0371, -0.0245, -0.0028],
#                       [-0.0058,  0.0096, -0.0058,  ..., -0.0361, -0.0064, -0.0289]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.0.input_layernorm.weight',
#               tensor([1.0225, 1.0215, 1.0322,  ..., 1.0283, 1.0205, 1.0020], device='cuda:0')),
#              ('gpt_neox.layers.0.input_layernorm.bias',
#               tensor([ 0.0049, -0.0098, -0.0223,  ...,  0.0134, -0.0051,  0.0237],
#                      device='cuda:0')),
#              ('gpt_neox.layers.0.post_attention_layernorm.weight',
#               tensor([0.9751, 0.9712, 0.9805,  ..., 0.9756, 0.9692, 1.0020], device='cuda:0')),
#              ('gpt_neox.layers.0.post_attention_layernorm.bias',
#               tensor([-0.0038, -0.0009, -0.0188,  ...,  0.0090,  0.0073,  0.0269],
#                      device='cuda:0')),
#              ('gpt_neox.layers.0.attention.rotary_emb.inv_freq',
#               tensor([1.0000e+00, 3.1616e-01, 9.9976e-02, 3.1616e-02, 1.0002e-02, 3.1624e-03,
#                       1.0004e-03, 3.1614e-04], device='cuda:0')),
#              ('gpt_neox.layers.0.attention.query_key_value.weight',
#               tensor([[-0.0033, -0.0027, -0.0101,  ...,  0.0382, -0.0188,  0.0371],
#                       [ 0.0106, -0.0087,  0.0452,  ...,  0.0204, -0.0105, -0.0069],
#                       [-0.0528, -0.0546, -0.0008,  ..., -0.0122, -0.0228, -0.0034],
#                       ...,
#                       [ 0.0149,  0.0006,  0.0164,  ..., -0.0361, -0.0285, -0.0376],
#                       [-0.0134, -0.0126,  0.0043,  ...,  0.0066, -0.0153, -0.0171],
#                       [ 0.0084,  0.0041, -0.0171,  ..., -0.0225,  0.0413, -0.0040]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.0.attention.query_key_value.bias',
#               tensor([ 0.0128, -0.0208, -0.0378,  ...,  0.0007, -0.0027, -0.0034],
#                      device='cuda:0')),
#              ('gpt_neox.layers.0.attention.dense.weight',
#               tensor([[ 0.0052, -0.0074, -0.0063,  ...,  0.0155, -0.0062,  0.0110],
#                       [ 0.0010,  0.0079, -0.0095,  ..., -0.0084,  0.0045, -0.0051],
#                       [ 0.0011,  0.0002, -0.0085,  ..., -0.0021, -0.0046, -0.0041],
#                       ...,
#                       [-0.0172,  0.0077,  0.0111,  ...,  0.0039,  0.0202,  0.0039],
#                       [ 0.0011, -0.0021, -0.0052,  ...,  0.0220, -0.0097, -0.0141],
#                       [ 0.0018, -0.0035,  0.0036,  ..., -0.0049, -0.0155,  0.0018]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.0.attention.dense.bias',
#               tensor([ 0.0104,  0.0013,  0.0023,  ...,  0.0009,  0.0021, -0.0023],
#                      device='cuda:0')),
#              ('gpt_neox.layers.0.mlp.dense_h_to_4h.weight',
#               tensor([[ 0.0072, -0.0234, -0.0003,  ..., -0.0318, -0.0179, -0.0183],
#                       [ 0.0338,  0.0366,  0.0261,  ...,  0.0306,  0.0141, -0.0231],
#                       [ 0.0073, -0.0033, -0.0224,  ..., -0.0258, -0.0255,  0.0163],
#                       ...,
#                       [-0.0388, -0.0106, -0.0042,  ..., -0.0194,  0.0075,  0.0298],
#                       [-0.0158,  0.0050, -0.0044,  ..., -0.0042,  0.0072,  0.0066],
#                       [ 0.0271,  0.0008, -0.0603,  ...,  0.0098, -0.0341, -0.0045]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.0.mlp.dense_h_to_4h.bias',
#               tensor([-0.0091, -0.0116, -0.0088,  ..., -0.0087, -0.0106, -0.0099],
#                      device='cuda:0')),
#              ('gpt_neox.layers.0.mlp.dense_4h_to_h.weight',
#               tensor([[-0.0046, -0.0052,  0.0032,  ..., -0.0134, -0.0030,  0.0033],
#                       [ 0.0042, -0.0039,  0.0129,  ..., -0.0037,  0.0025, -0.0114],
#                       [-0.0022,  0.0037, -0.0057,  ...,  0.0026, -0.0212, -0.0127],
#                       ...,
#                       [-0.0051,  0.0048, -0.0025,  ...,  0.0054, -0.0005, -0.0084],
#                       [ 0.0003, -0.0055, -0.0021,  ..., -0.0139, -0.0100,  0.0029],
#                       [ 0.0019, -0.0011,  0.0034,  ..., -0.0030,  0.0115, -0.0021]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.0.mlp.dense_4h_to_h.bias',
#               tensor([ 0.0104,  0.0013,  0.0023,  ...,  0.0009,  0.0021, -0.0023],
#                      device='cuda:0')),
#              ('gpt_neox.layers.1.input_layernorm.weight',
#               tensor([1.0039, 1.0156, 1.0049,  ..., 1.0117, 1.0010, 1.0195], device='cuda:0')),
#              ('gpt_neox.layers.1.input_layernorm.bias',
#               tensor([ 0.0212, -0.0011, -0.0004,  ...,  0.0022,  0.0075, -0.0123],
#                      device='cuda:0')),
#              ('gpt_neox.layers.1.post_attention_layernorm.weight',
#               tensor([1.0166, 1.0303, 1.0186,  ..., 1.0273, 1.0332, 1.0264], device='cuda:0')),
#              ('gpt_neox.layers.1.post_attention_layernorm.bias',
#               tensor([ 0.0095,  0.0060,  0.0066,  ...,  0.0083,  0.0102, -0.0030],
#                      device='cuda:0')),
#              ('gpt_neox.layers.1.attention.rotary_emb.inv_freq',
#               tensor([1.0000e+00, 3.1616e-01, 9.9976e-02, 3.1616e-02, 1.0002e-02, 3.1624e-03,
#                       1.0004e-03, 3.1614e-04], device='cuda:0')),
#              ('gpt_neox.layers.1.attention.query_key_value.weight',
#               tensor([[-0.0014, -0.0402,  0.0309,  ..., -0.0354,  0.0505, -0.0158],
#                       [ 0.0141, -0.0185,  0.0245,  ..., -0.0189,  0.0276,  0.0252],
#                       [ 0.0157, -0.0146, -0.0658,  ...,  0.0035,  0.0050, -0.0010],
#                       ...,
#                       [ 0.0240, -0.0429, -0.0011,  ...,  0.0376,  0.0010,  0.0112],
#                       [-0.0453,  0.0005, -0.0049,  ..., -0.0112,  0.0071,  0.0005],
#                       [ 0.0035, -0.0307, -0.0201,  ..., -0.0004, -0.0027,  0.0091]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.1.attention.query_key_value.bias',
#               tensor([ 0.0097, -0.0039,  0.0150,  ..., -0.0013, -0.0039, -0.0007],
#                      device='cuda:0')),
#              ('gpt_neox.layers.1.attention.dense.weight',
#               tensor([[ 0.0009, -0.0079,  0.0005,  ..., -0.0007, -0.0103,  0.0264],
#                       [ 0.0043, -0.0052, -0.0060,  ..., -0.0084, -0.0104,  0.0060],
#                       [-0.0072,  0.0230, -0.0165,  ..., -0.0023, -0.0112, -0.0015],
#                       ...,
#                       [-0.0018, -0.0184,  0.0067,  ..., -0.0103,  0.0101,  0.0024],
#                       [ 0.0079, -0.0018,  0.0009,  ..., -0.0113, -0.0020, -0.0046],
#                       [ 0.0056, -0.0149, -0.0158,  ..., -0.0027,  0.0005, -0.0089]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.1.attention.dense.bias',
#               tensor([ 0.0007, -0.0009,  0.0036,  ..., -0.0030, -0.0037,  0.0088],
#                      device='cuda:0')),
#              ('gpt_neox.layers.1.mlp.dense_h_to_4h.weight',
#               tensor([[-0.0058,  0.0350, -0.0145,  ...,  0.0045,  0.0173,  0.0414],
#                       [-0.0181, -0.0008, -0.0180,  ..., -0.0015, -0.0275,  0.0444],
#                       [ 0.0085, -0.0069,  0.0265,  ..., -0.0073, -0.0257, -0.0018],
#                       ...,
#                       [-0.0333,  0.0030, -0.0293,  ..., -0.0136,  0.0261, -0.0431],
#                       [-0.0071, -0.0126, -0.0147,  ..., -0.0335,  0.0025, -0.0173],
#                       [ 0.0314, -0.0055,  0.0153,  ..., -0.0007,  0.0345,  0.0076]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.1.mlp.dense_h_to_4h.bias',
#               tensor([-0.0058, -0.0054, -0.0093,  ..., -0.0080, -0.0029, -0.0082],
#                      device='cuda:0')),
#              ('gpt_neox.layers.1.mlp.dense_4h_to_h.weight',
#               tensor([[-0.0014, -0.0042,  0.0050,  ..., -0.0042, -0.0005,  0.0034],
#                       [-0.0084, -0.0052,  0.0007,  ...,  0.0021, -0.0037,  0.0128],
#                       [-0.0057, -0.0066, -0.0017,  ...,  0.0023, -0.0014,  0.0082],
#                       ...,
#                       [-0.0030, -0.0077, -0.0011,  ..., -0.0060,  0.0051, -0.0059],
#                       [-0.0045,  0.0086,  0.0117,  ...,  0.0055,  0.0058, -0.0037],
#                       [ 0.0015, -0.0017,  0.0032,  ...,  0.0022, -0.0004, -0.0031]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.1.mlp.dense_4h_to_h.bias',
#               tensor([ 0.0007, -0.0009,  0.0036,  ..., -0.0030, -0.0037,  0.0088],
#                      device='cuda:0')),
#              ('gpt_neox.layers.2.input_layernorm.weight',
#               tensor([0.9790, 0.9697, 0.9697,  ..., 0.9697, 0.9766, 0.9814], device='cuda:0')),
#              ('gpt_neox.layers.2.input_layernorm.bias',
#               tensor([-0.0065,  0.0084, -0.0073,  ...,  0.0055, -0.0050, -0.0054],
#                      device='cuda:0')),
#              ('gpt_neox.layers.2.post_attention_layernorm.weight',
#               tensor([1.0479, 1.0596, 1.0615,  ..., 1.0576, 1.0410, 1.0742], device='cuda:0')),
#              ('gpt_neox.layers.2.post_attention_layernorm.bias',
#               tensor([-0.0061, -0.0219,  0.0210,  ..., -0.0208, -0.0009,  0.0265],
#                      device='cuda:0')),
#              ('gpt_neox.layers.2.attention.rotary_emb.inv_freq',
#               tensor([1.0000e+00, 3.1616e-01, 9.9976e-02, 3.1616e-02, 1.0002e-02, 3.1624e-03,
#                       1.0004e-03, 3.1614e-04], device='cuda:0')),
#              ('gpt_neox.layers.2.attention.query_key_value.weight',
#               tensor([[-0.0498, -0.0197, -0.0040,  ..., -0.0117,  0.0070, -0.0235],
#                       [-0.0047, -0.0043, -0.0301,  ..., -0.0048,  0.0181, -0.0241],
#                       [-0.0320,  0.0180,  0.0144,  ...,  0.0003,  0.0094, -0.0122],
#                       ...,
#                       [ 0.0442,  0.0120,  0.0105,  ...,  0.0074,  0.0123, -0.0377],
#                       [ 0.0366, -0.0127,  0.0459,  ..., -0.0016,  0.0223,  0.0136],
#                       [ 0.0457, -0.0125,  0.0161,  ...,  0.0139,  0.0126,  0.0157]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.2.attention.query_key_value.bias',
#               tensor([ 0.0062,  0.0028,  0.0113,  ..., -0.0017,  0.0034, -0.0029],
#                      device='cuda:0')),
#              ('gpt_neox.layers.2.attention.dense.weight',
#               tensor([[ 0.0040,  0.0002,  0.0014,  ...,  0.0033,  0.0058, -0.0046],
#                       [ 0.0031, -0.0013, -0.0146,  ..., -0.0043,  0.0028,  0.0019],
#                       [ 0.0032,  0.0027,  0.0023,  ..., -0.0024, -0.0037, -0.0068],
#                       ...,
#                       [ 0.0048,  0.0133, -0.0025,  ...,  0.0044,  0.0042,  0.0064],
#                       [-0.0023,  0.0069,  0.0008,  ..., -0.0040, -0.0068, -0.0056],
#                       [-0.0005,  0.0009, -0.0024,  ...,  0.0056,  0.0010,  0.0105]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.2.attention.dense.bias',
#               tensor([ 0.0056,  0.0002,  0.0023,  ...,  0.0015, -0.0019,  0.0050],
#                      device='cuda:0')),
#              ('gpt_neox.layers.2.mlp.dense_h_to_4h.weight',
#               tensor([[-0.0084,  0.0061, -0.0242,  ...,  0.0190, -0.0093,  0.0034],
#                       [ 0.0070, -0.0422, -0.0079,  ...,  0.0165,  0.0055,  0.0321],
#                       [-0.0175,  0.0038, -0.0111,  ..., -0.0115, -0.0141, -0.0039],
#                       ...,
#                       [-0.0233,  0.0165, -0.0656,  ...,  0.0003,  0.0185, -0.0355],
#                       [-0.0289, -0.0085,  0.0196,  ...,  0.0387, -0.0532,  0.0123],
#                       [ 0.0241,  0.0075,  0.0283,  ...,  0.0200,  0.0385,  0.0013]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.2.mlp.dense_h_to_4h.bias',
#               tensor([-0.0098, -0.0116, -0.0087,  ..., -0.0110, -0.0087, -0.0072],
#                      device='cuda:0')),
#              ('gpt_neox.layers.2.mlp.dense_4h_to_h.weight',
#               tensor([[ 0.0006, -0.0113, -0.0034,  ..., -0.0181,  0.0028, -0.0027],
#                       [-0.0098,  0.0029, -0.0066,  ...,  0.0006,  0.0006, -0.0017],
#                       [ 0.0011, -0.0094, -0.0096,  ..., -0.0006, -0.0032, -0.0049],
#                       ...,
#                       [ 0.0022, -0.0077,  0.0153,  ..., -0.0057,  0.0054, -0.0012],
#                       [-0.0015,  0.0177,  0.0069,  ...,  0.0059, -0.0012, -0.0086],
#                       [-0.0035,  0.0013, -0.0018,  ..., -0.0008,  0.0111,  0.0043]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.2.mlp.dense_4h_to_h.bias',
#               tensor([ 0.0056,  0.0002,  0.0023,  ...,  0.0015, -0.0019,  0.0050],
#                      device='cuda:0')),
#              ('gpt_neox.layers.3.input_layernorm.weight',
#               tensor([0.9756, 0.9790, 0.9775,  ..., 0.9736, 0.9619, 0.9526], device='cuda:0')),
#              ('gpt_neox.layers.3.input_layernorm.bias',
#               tensor([-0.0109, -0.0013, -0.0052,  ...,  0.0009,  0.0075, -0.0012],
#                      device='cuda:0')),
#              ('gpt_neox.layers.3.post_attention_layernorm.weight',
#               tensor([1.0430, 1.0645, 1.0732,  ..., 1.0957, 1.0703, 1.0850], device='cuda:0')),
#              ('gpt_neox.layers.3.post_attention_layernorm.bias',
#               tensor([-0.0001, -0.0158,  0.0155,  ...,  0.0202, -0.0111,  0.0255],
#                      device='cuda:0')),
#              ('gpt_neox.layers.3.attention.rotary_emb.inv_freq',
#               tensor([1.0000e+00, 3.1616e-01, 9.9976e-02, 3.1616e-02, 1.0002e-02, 3.1624e-03,
#                       1.0004e-03, 3.1614e-04], device='cuda:0')),
#              ('gpt_neox.layers.3.attention.query_key_value.weight',
#               tensor([[ 0.0033, -0.0080,  0.0011,  ..., -0.0352, -0.0342, -0.0037],
#                       [ 0.0227, -0.0011, -0.0099,  ..., -0.0223,  0.0177, -0.0264],
#                       [ 0.0230, -0.0050,  0.0025,  ..., -0.0109,  0.0181, -0.0136],
#                       ...,
#                       [ 0.0088, -0.0156,  0.0022,  ...,  0.0312, -0.0091,  0.0423],
#                       [-0.0140,  0.0120, -0.0265,  ...,  0.0150, -0.0075, -0.0086],
#                       [ 0.0184, -0.0095,  0.0060,  ...,  0.0181,  0.0166, -0.0375]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.3.attention.query_key_value.bias',
#               tensor([-0.0023,  0.0075, -0.0056,  ..., -0.0021, -0.0025, -0.0003],
#                      device='cuda:0')),
#              ('gpt_neox.layers.3.attention.dense.weight',
#               tensor([[ 0.0118, -0.0108, -0.0058,  ...,  0.0045,  0.0074,  0.0058],
#                       [ 0.0024, -0.0034, -0.0052,  ..., -0.0105,  0.0041, -0.0021],
#                       [-0.0074,  0.0007, -0.0034,  ..., -0.0006, -0.0159,  0.0023],
#                       ...,
#                       [-0.0038, -0.0009, -0.0017,  ...,  0.0087,  0.0084,  0.0020],
#                       [-0.0079,  0.0040,  0.0036,  ...,  0.0098, -0.0024,  0.0010],
#                       [ 0.0055,  0.0194,  0.0055,  ..., -0.0049, -0.0069,  0.0007]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.3.attention.dense.bias',
#               tensor([ 0.0121,  0.0060,  0.0002,  ..., -0.0026, -0.0030,  0.0004],
#                      device='cuda:0')),
#              ('gpt_neox.layers.3.mlp.dense_h_to_4h.weight',
#               tensor([[ 0.0043,  0.0062,  0.0316,  ...,  0.0291,  0.0273, -0.0429],
#                       [ 0.0033,  0.0192,  0.0106,  ..., -0.0011,  0.0030, -0.0068],
#                       [-0.0137, -0.0420,  0.0440,  ...,  0.0233,  0.0200, -0.0152],
#                       ...,
#                       [-0.0045,  0.0032,  0.0399,  ...,  0.0125, -0.0119,  0.0130],
#                       [ 0.0154,  0.0069,  0.0230,  ..., -0.0162,  0.0065, -0.0070],
#                       [-0.0268, -0.0219,  0.0358,  ...,  0.0242,  0.0064, -0.0180]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.3.mlp.dense_h_to_4h.bias',
#               tensor([-0.0048, -0.0097, -0.0135,  ..., -0.0090, -0.0119, -0.0081],
#                      device='cuda:0')),
#              ('gpt_neox.layers.3.mlp.dense_4h_to_h.weight',
#               tensor([[-0.0060, -0.0104,  0.0045,  ..., -0.0107,  0.0049,  0.0038],
#                       [-0.0013, -0.0150, -0.0052,  ...,  0.0073,  0.0005, -0.0039],
#                       [ 0.0069,  0.0020, -0.0073,  ...,  0.0049,  0.0056,  0.0089],
#                       ...,
#                       [-0.0104,  0.0055,  0.0002,  ..., -0.0088, -0.0058,  0.0010],
#                       [ 0.0184,  0.0139,  0.0010,  ...,  0.0170, -0.0015,  0.0041],
#                       [ 0.0175,  0.0026,  0.0002,  ..., -0.0047, -0.0042, -0.0112]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.3.mlp.dense_4h_to_h.bias',
#               tensor([ 0.0121,  0.0060,  0.0002,  ..., -0.0026, -0.0030,  0.0004],
#                      device='cuda:0')),
#              ('gpt_neox.layers.4.input_layernorm.weight',
#               tensor([0.9824, 0.9834, 0.9819,  ..., 0.9722, 0.9766, 0.9678], device='cuda:0')),
#              ('gpt_neox.layers.4.input_layernorm.bias',
#               tensor([-0.0109,  0.0009, -0.0049,  ...,  0.0143,  0.0107, -0.0014],
#                      device='cuda:0')),
#              ('gpt_neox.layers.4.post_attention_layernorm.weight',
#               tensor([1.0762, 1.0801, 1.0713,  ..., 1.0742, 1.0811, 1.0938], device='cuda:0')),
#              ('gpt_neox.layers.4.post_attention_layernorm.bias',
#               tensor([ 0.0263,  0.0133, -0.0045,  ...,  0.0021, -0.0251,  0.0226],
#                      device='cuda:0')),
#              ('gpt_neox.layers.4.attention.rotary_emb.inv_freq',
#               tensor([1.0000e+00, 3.1616e-01, 9.9976e-02, 3.1616e-02, 1.0002e-02, 3.1624e-03,
#                       1.0004e-03, 3.1614e-04], device='cuda:0')),
#              ('gpt_neox.layers.4.attention.query_key_value.weight',
#               tensor([[-0.0077, -0.0255, -0.0526,  ..., -0.0223, -0.0009, -0.0202],
#                       [ 0.0125, -0.0019, -0.0155,  ...,  0.0363,  0.0049, -0.0181],
#                       [ 0.0004, -0.0209,  0.0033,  ..., -0.0002,  0.0148,  0.0166],
#                       ...,
#                       [-0.0066, -0.0090,  0.0003,  ...,  0.0003,  0.0017, -0.0030],
#                       [ 0.0114,  0.0551, -0.0205,  ..., -0.0196,  0.0300, -0.0148],
#                       [ 0.0195, -0.0153, -0.0160,  ...,  0.0177, -0.0090,  0.0019]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.4.attention.query_key_value.bias',
#               tensor([-0.0280, -0.0352, -0.0049,  ...,  0.0006, -0.0021,  0.0010],
#                      device='cuda:0')),
#              ('gpt_neox.layers.4.attention.dense.weight',
#               tensor([[ 8.8577e-03,  5.3329e-03,  5.1594e-04,  ...,  1.8978e-03,
#                        -1.0223e-02,  1.5930e-02],
#                       [ 2.2507e-03,  1.9064e-03, -3.9043e-03,  ..., -7.2975e-03,
#                        -9.2545e-03,  1.5717e-02],
#                       [ 5.4741e-03, -7.9803e-03,  1.0620e-02,  ...,  1.3496e-02,
#                         4.0817e-03,  2.6932e-03],
#                       ...,
#                       [ 7.1602e-03, -1.4053e-02, -3.1590e-04,  ...,  8.3466e-03,
#                        -1.5793e-02, -2.8896e-03],
#                       [ 5.8899e-03, -1.4473e-02, -1.4572e-03,  ...,  5.0068e-05,
#                         1.1017e-02,  1.6809e-04],
#                       [-1.4771e-02, -2.4399e-02, -2.2766e-02,  ...,  5.3329e-03,
#                         1.5030e-02,  1.6956e-03]], device='cuda:0')),
#              ('gpt_neox.layers.4.attention.dense.bias',
#               tensor([ 0.0137,  0.0037,  0.0040,  ..., -0.0069, -0.0010, -0.0034],
#                      device='cuda:0')),
#              ('gpt_neox.layers.4.mlp.dense_h_to_4h.weight',
#               tensor([[ 0.0072, -0.0115,  0.0142,  ...,  0.0001,  0.0048, -0.0422],
#                       [ 0.0112,  0.0014,  0.0152,  ...,  0.0022, -0.0220, -0.0349],
#                       [-0.0110,  0.0025, -0.0177,  ..., -0.0210,  0.0350,  0.0186],
#                       ...,
#                       [ 0.0250,  0.0099, -0.0204,  ...,  0.0180,  0.0030, -0.0276],
#                       [-0.0291,  0.0026,  0.0268,  ..., -0.0413,  0.0551,  0.0272],
#                       [ 0.0137,  0.0245,  0.0265,  ...,  0.0160,  0.0130,  0.0019]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.4.mlp.dense_h_to_4h.bias',
#               tensor([-0.0087, -0.0120, -0.0064,  ..., -0.0037, -0.0098, -0.0091],
#                      device='cuda:0')),
#              ('gpt_neox.layers.4.mlp.dense_4h_to_h.weight',
#               tensor([[ 0.0039, -0.0020,  0.0067,  ..., -0.0038,  0.0013,  0.0039],
#                       [ 0.0012,  0.0023,  0.0046,  ...,  0.0119, -0.0012, -0.0085],
#                       [ 0.0041,  0.0083,  0.0016,  ..., -0.0024,  0.0050,  0.0049],
#                       ...,
#                       [-0.0078,  0.0037,  0.0081,  ..., -0.0148,  0.0060, -0.0132],
#                       [-0.0105,  0.0047,  0.0013,  ..., -0.0127, -0.0087, -0.0177],
#                       [-0.0029,  0.0027,  0.0055,  ..., -0.0002, -0.0067, -0.0068]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.4.mlp.dense_4h_to_h.bias',
#               tensor([ 0.0137,  0.0037,  0.0040,  ..., -0.0069, -0.0010, -0.0034],
#                      device='cuda:0')),
#              ('gpt_neox.layers.5.input_layernorm.weight',
#               tensor([1.0029, 0.9873, 0.9888,  ..., 0.9927, 0.9917, 0.9849], device='cuda:0')),
#              ('gpt_neox.layers.5.input_layernorm.bias',
#               tensor([ 0.0145,  0.0005, -0.0050,  ...,  0.0059, -0.0001, -0.0035],
#                      device='cuda:0')),
#              ('gpt_neox.layers.5.post_attention_layernorm.weight',
#               tensor([1.0801, 1.0928, 1.0840,  ..., 1.1035, 1.0801, 1.0938], device='cuda:0')),
#              ('gpt_neox.layers.5.post_attention_layernorm.bias',
#               tensor([ 0.0366,  0.0147,  0.0206,  ..., -0.0279, -0.0160,  0.0083],
#                      device='cuda:0')),
#              ('gpt_neox.layers.5.attention.rotary_emb.inv_freq',
#               tensor([1.0000e+00, 3.1616e-01, 9.9976e-02, 3.1616e-02, 1.0002e-02, 3.1624e-03,
#                       1.0004e-03, 3.1614e-04], device='cuda:0')),
#              ('gpt_neox.layers.5.attention.query_key_value.weight',
#               tensor([[ 0.0116,  0.0101,  0.0184,  ..., -0.0460,  0.0135,  0.0056],
#                       [ 0.0099, -0.0202,  0.0005,  ..., -0.0044, -0.0536,  0.0054],
#                       [-0.0385, -0.0052, -0.0215,  ..., -0.0045,  0.0427, -0.0192],
#                       ...,
#                       [-0.0264, -0.0363,  0.0102,  ...,  0.0177, -0.0263,  0.0082],
#                       [ 0.0177, -0.0019, -0.0309,  ..., -0.0109, -0.0092, -0.0062],
#                       [ 0.0047,  0.0201, -0.0015,  ...,  0.0358,  0.0118, -0.0186]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.5.attention.query_key_value.bias',
#               tensor([-0.0039,  0.0145,  0.0135,  ..., -0.0016, -0.0026, -0.0010],
#                      device='cuda:0')),
#              ('gpt_neox.layers.5.attention.dense.weight',
#               tensor([[ 0.0097, -0.0063, -0.0063,  ..., -0.0026, -0.0018, -0.0026],
#                       [ 0.0006,  0.0051,  0.0079,  ..., -0.0044,  0.0072,  0.0087],
#                       [ 0.0009, -0.0077, -0.0009,  ..., -0.0004,  0.0114,  0.0013],
#                       ...,
#                       [-0.0090, -0.0011, -0.0098,  ..., -0.0067, -0.0046, -0.0098],
#                       [ 0.0056, -0.0022, -0.0062,  ..., -0.0056,  0.0060, -0.0214],
#                       [ 0.0027, -0.0041,  0.0039,  ..., -0.0086,  0.0054,  0.0066]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.5.attention.dense.bias',
#               tensor([ 0.0098,  0.0015,  0.0046,  ..., -0.0067,  0.0012, -0.0032],
#                      device='cuda:0')),
#              ('gpt_neox.layers.5.mlp.dense_h_to_4h.weight',
#               tensor([[ 0.0273,  0.0198, -0.0151,  ...,  0.0360, -0.0029,  0.0088],
#                       [ 0.0001,  0.0233,  0.0006,  ...,  0.0282,  0.0064,  0.0027],
#                       [ 0.0202,  0.0168,  0.0150,  ..., -0.0010,  0.0268, -0.0059],
#                       ...,
#                       [-0.0203, -0.0253,  0.0335,  ...,  0.0017,  0.0187,  0.0130],
#                       [ 0.0046, -0.0162, -0.0398,  ...,  0.0023,  0.0089,  0.0093],
#                       [-0.0167,  0.0125,  0.0085,  ..., -0.0278,  0.0196,  0.0311]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.5.mlp.dense_h_to_4h.bias',
#               tensor([-0.0080, -0.0074, -0.0083,  ..., -0.0119, -0.0127, -0.0121],
#                      device='cuda:0')),
#              ('gpt_neox.layers.5.mlp.dense_4h_to_h.weight',
#               tensor([[ 0.0042, -0.0020,  0.0112,  ..., -0.0134, -0.0045,  0.0070],
#                       [ 0.0097, -0.0008,  0.0023,  ..., -0.0026,  0.0079,  0.0164],
#                       [-0.0115,  0.0085, -0.0028,  ...,  0.0205, -0.0052,  0.0066],
#                       ...,
#                       [ 0.0037, -0.0122, -0.0076,  ...,  0.0051, -0.0081,  0.0096],
#                       [-0.0019,  0.0107, -0.0040,  ...,  0.0097,  0.0020, -0.0044],
#                       [-0.0009,  0.0023,  0.0002,  ..., -0.0086, -0.0075, -0.0007]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.5.mlp.dense_4h_to_h.bias',
#               tensor([ 0.0098,  0.0015,  0.0046,  ..., -0.0067,  0.0012, -0.0032],
#                      device='cuda:0')),
#              ('gpt_neox.layers.6.input_layernorm.weight',
#               tensor([0.9956, 0.9990, 0.9990,  ..., 0.9951, 0.9990, 0.9946], device='cuda:0')),
#              ('gpt_neox.layers.6.input_layernorm.bias',
#               tensor([ 0.0013,  0.0029, -0.0080,  ...,  0.0059,  0.0016, -0.0054],
#                      device='cuda:0')),
#              ('gpt_neox.layers.6.post_attention_layernorm.weight',
#               tensor([1.0898, 1.0996, 1.0889,  ..., 1.1182, 1.0693, 1.1064], device='cuda:0')),
#              ('gpt_neox.layers.6.post_attention_layernorm.bias',
#               tensor([ 0.0424,  0.0093,  0.0273,  ..., -0.0346, -0.0183, -0.0013],
#                      device='cuda:0')),
#              ('gpt_neox.layers.6.attention.rotary_emb.inv_freq',
#               tensor([1.0000e+00, 3.1616e-01, 9.9976e-02, 3.1616e-02, 1.0002e-02, 3.1624e-03,
#                       1.0004e-03, 3.1614e-04], device='cuda:0')),
#              ('gpt_neox.layers.6.attention.query_key_value.weight',
#               tensor([[-0.0060,  0.0039,  0.0032,  ...,  0.0271, -0.0241, -0.0332],
#                       [ 0.0182, -0.0164,  0.0278,  ..., -0.0201, -0.0303,  0.0050],
#                       [ 0.0008,  0.0353, -0.0031,  ..., -0.0116, -0.0010,  0.0118],
#                       ...,
#                       [ 0.0136,  0.0150,  0.0215,  ..., -0.0162, -0.0119,  0.0167],
#                       [-0.0284,  0.0158,  0.0153,  ..., -0.0141, -0.0119, -0.0025],
#                       [ 0.0030, -0.0251, -0.0124,  ...,  0.0081,  0.0356,  0.0135]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.6.attention.query_key_value.bias',
#               tensor([ 0.0097,  0.0033, -0.0170,  ...,  0.0032, -0.0008,  0.0004],
#                      device='cuda:0')),
#              ('gpt_neox.layers.6.attention.dense.weight',
#               tensor([[-0.0032, -0.0022, -0.0011,  ..., -0.0079, -0.0009,  0.0073],
#                       [ 0.0147, -0.0180,  0.0051,  ..., -0.0088, -0.0071,  0.0043],
#                       [ 0.0109, -0.0153,  0.0046,  ..., -0.0051, -0.0029, -0.0044],
#                       ...,
#                       [ 0.0081, -0.0073,  0.0108,  ..., -0.0022,  0.0032, -0.0032],
#                       [-0.0063,  0.0084,  0.0004,  ..., -0.0066,  0.0071, -0.0084],
#                       [ 0.0172,  0.0182, -0.0004,  ..., -0.0034,  0.0022, -0.0078]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.6.attention.dense.bias',
#               tensor([ 0.0092,  0.0002,  0.0036,  ..., -0.0056,  0.0035, -0.0009],
#                      device='cuda:0')),
#              ('gpt_neox.layers.6.mlp.dense_h_to_4h.weight',
#               tensor([[ 0.0078,  0.0103, -0.0366,  ...,  0.0197,  0.0166, -0.0052],
#                       [-0.0356,  0.0287,  0.0140,  ..., -0.0169,  0.0452,  0.0127],
#                       [ 0.0415,  0.0125,  0.0109,  ..., -0.0220, -0.0005, -0.0106],
#                       ...,
#                       [-0.0031, -0.0399,  0.0075,  ..., -0.0264, -0.0311,  0.0309],
#                       [ 0.0057,  0.0521, -0.0415,  ...,  0.0221, -0.0177,  0.0150],
#                       [-0.0717, -0.0300,  0.0012,  ...,  0.0563,  0.0015,  0.0054]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.6.mlp.dense_h_to_4h.bias',
#               tensor([-0.0087, -0.0110, -0.0038,  ..., -0.0112, -0.0062, -0.0109],
#                      device='cuda:0')),
#              ('gpt_neox.layers.6.mlp.dense_4h_to_h.weight',
#               tensor([[ 3.2501e-03,  6.9320e-05, -6.1035e-03,  ..., -3.3016e-03,
#                         6.9580e-03, -5.2223e-03],
#                       [ 6.8588e-03, -1.5823e-02,  6.3324e-03,  ...,  9.4528e-03,
#                        -3.6602e-03, -4.8409e-03],
#                       [-9.1019e-03, -3.0766e-03,  8.3923e-03,  ...,  1.8673e-03,
#                         2.1839e-03, -7.7896e-03],
#                       ...,
#                       [-4.1046e-03,  1.5427e-02, -1.0956e-02,  ..., -9.6989e-04,
#                        -1.0696e-02, -1.3800e-03],
#                       [ 2.5215e-03,  2.2240e-03,  2.4490e-03,  ...,  1.4359e-02,
#                        -1.9272e-02, -6.2828e-03],
#                       [-7.0333e-06,  1.3847e-02, -1.1110e-03,  ...,  3.1242e-03,
#                        -1.4099e-02, -4.4518e-03]], device='cuda:0')),
#              ('gpt_neox.layers.6.mlp.dense_4h_to_h.bias',
#               tensor([ 0.0092,  0.0002,  0.0036,  ..., -0.0056,  0.0035, -0.0009],
#                      device='cuda:0')),
#              ('gpt_neox.layers.7.input_layernorm.weight',
#               tensor([0.9985, 0.9854, 0.9937,  ..., 0.9878, 1.0000, 0.9854], device='cuda:0')),
#              ('gpt_neox.layers.7.input_layernorm.bias',
#               tensor([ 0.0083, -0.0059,  0.0026,  ..., -0.0014,  0.0016, -0.0070],
#                      device='cuda:0')),
#              ('gpt_neox.layers.7.post_attention_layernorm.weight',
#               tensor([1.0889, 1.1113, 1.0986,  ..., 1.1377, 1.0830, 1.0977], device='cuda:0')),
#              ('gpt_neox.layers.7.post_attention_layernorm.bias',
#               tensor([ 0.0332,  0.0169,  0.0146,  ..., -0.0337,  0.0005,  0.0027],
#                      device='cuda:0')),
#              ('gpt_neox.layers.7.attention.rotary_emb.inv_freq',
#               tensor([1.0000e+00, 3.1616e-01, 9.9976e-02, 3.1616e-02, 1.0002e-02, 3.1624e-03,
#                       1.0004e-03, 3.1614e-04], device='cuda:0')),
#              ('gpt_neox.layers.7.attention.query_key_value.weight',
#               tensor([[ 0.0084, -0.0662,  0.0271,  ..., -0.0140, -0.0304, -0.0068],
#                       [-0.0018,  0.0257, -0.0038,  ..., -0.0204,  0.0211,  0.0343],
#                       [ 0.0127, -0.0127, -0.0304,  ..., -0.0070,  0.0125,  0.0145],
#                       ...,
#                       [ 0.0163,  0.0288, -0.0143,  ...,  0.0192, -0.0008,  0.0034],
#                       [-0.0035,  0.0123,  0.0263,  ..., -0.0153, -0.0022, -0.0049],
#                       [ 0.0159,  0.0034, -0.0345,  ..., -0.0102, -0.0239,  0.0192]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.7.attention.query_key_value.bias',
#               tensor([ 0.0055, -0.0081,  0.0070,  ..., -0.0012, -0.0027, -0.0016],
#                      device='cuda:0')),
#              ('gpt_neox.layers.7.attention.dense.weight',
#               tensor([[ 0.0154,  0.0093,  0.0130,  ...,  0.0052,  0.0096, -0.0053],
#                       [-0.0119, -0.0012, -0.0018,  ..., -0.0126, -0.0019,  0.0031],
#                       [ 0.0156, -0.0006, -0.0084,  ..., -0.0088, -0.0006,  0.0067],
#                       ...,
#                       [-0.0094, -0.0175, -0.0054,  ...,  0.0083, -0.0091,  0.0050],
#                       [-0.0027, -0.0068, -0.0016,  ...,  0.0084, -0.0039,  0.0008],
#                       [-0.0101, -0.0129, -0.0022,  ..., -0.0206, -0.0110, -0.0064]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.7.attention.dense.bias',
#               tensor([ 0.0080,  0.0007,  0.0028,  ..., -0.0044,  0.0038,  0.0011],
#                      device='cuda:0')),
#              ('gpt_neox.layers.7.mlp.dense_h_to_4h.weight',
#               tensor([[ 0.0097, -0.0309, -0.0198,  ...,  0.0194,  0.0222, -0.0072],
#                       [-0.0257, -0.0019, -0.0031,  ...,  0.0111,  0.0012, -0.0303],
#                       [ 0.0361, -0.0364, -0.0030,  ...,  0.0245, -0.0374, -0.0406],
#                       ...,
#                       [-0.0283, -0.0133,  0.0316,  ...,  0.0245, -0.0098,  0.0235],
#                       [-0.0148,  0.0129, -0.0234,  ...,  0.0054,  0.0010, -0.0382],
#                       [-0.0560, -0.0462, -0.0035,  ..., -0.0277,  0.0202, -0.0259]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.7.mlp.dense_h_to_4h.bias',
#               tensor([-0.0117, -0.0043, -0.0056,  ..., -0.0122, -0.0109, -0.0044],
#                      device='cuda:0')),
#              ('gpt_neox.layers.7.mlp.dense_4h_to_h.weight',
#               tensor([[-1.2619e-02,  1.6937e-02, -9.6588e-03,  ..., -1.4198e-02,
#                         1.0139e-02,  1.3504e-02],
#                       [ 3.5167e-05, -4.8714e-03, -1.3916e-02,  ..., -6.0158e-03,
#                         7.2784e-03, -1.0025e-02],
#                       [-5.6725e-03, -4.2839e-03, -3.9330e-03,  ..., -1.0815e-03,
#                        -8.3313e-03,  8.5068e-03],
#                       ...,
#                       [ 8.0032e-03,  1.0368e-02, -8.9264e-03,  ..., -3.4142e-04,
#                         1.9180e-02,  8.5402e-04],
#                       [ 1.5717e-02, -2.4605e-03, -8.0414e-03,  ...,  5.1231e-03,
#                        -4.6492e-04, -8.2092e-03],
#                       [-1.4801e-02, -1.6525e-02, -1.5402e-04,  ..., -9.5701e-04,
#                         9.0637e-03,  1.2901e-02]], device='cuda:0')),
#              ('gpt_neox.layers.7.mlp.dense_4h_to_h.bias',
#               tensor([ 0.0080,  0.0007,  0.0028,  ..., -0.0044,  0.0038,  0.0011],
#                      device='cuda:0')),
#              ('gpt_neox.layers.8.input_layernorm.weight',
#               tensor([1.0166, 0.9951, 1.0166,  ..., 1.0059, 1.0078, 0.9951], device='cuda:0')),
#              ('gpt_neox.layers.8.input_layernorm.bias',
#               tensor([ 0.0183,  0.0052,  0.0009,  ...,  0.0012, -0.0102, -0.0114],
#                      device='cuda:0')),
#              ('gpt_neox.layers.8.post_attention_layernorm.weight',
#               tensor([1.1006, 1.0996, 1.1006,  ..., 1.1357, 1.0820, 1.1143], device='cuda:0')),
#              ('gpt_neox.layers.8.post_attention_layernorm.bias',
#               tensor([ 0.0529,  0.0245,  0.0209,  ..., -0.0320,  0.0124,  0.0153],
#                      device='cuda:0')),
#              ('gpt_neox.layers.8.attention.rotary_emb.inv_freq',
#               tensor([1.0000e+00, 3.1616e-01, 9.9976e-02, 3.1616e-02, 1.0002e-02, 3.1624e-03,
#                       1.0004e-03, 3.1614e-04], device='cuda:0')),
#              ('gpt_neox.layers.8.attention.query_key_value.weight',
#               tensor([[-0.0078,  0.0181, -0.0098,  ...,  0.0155,  0.0113,  0.0108],
#                       [ 0.0043,  0.0585,  0.0311,  ..., -0.0406, -0.0259, -0.0232],
#                       [ 0.0097,  0.0061,  0.0107,  ...,  0.0214,  0.0001, -0.0083],
#                       ...,
#                       [-0.0090, -0.0850,  0.0053,  ..., -0.0283,  0.0081, -0.0221],
#                       [-0.0629,  0.0327, -0.0285,  ..., -0.0156, -0.0019, -0.0170],
#                       [ 0.0312, -0.0174,  0.0339,  ...,  0.0041, -0.0009, -0.0066]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.8.attention.query_key_value.bias',
#               tensor([-0.0055,  0.0093,  0.0116,  ..., -0.0006,  0.0002,  0.0027],
#                      device='cuda:0')),
#              ('gpt_neox.layers.8.attention.dense.weight',
#               tensor([[ 0.0005, -0.0025, -0.0072,  ...,  0.0014, -0.0030,  0.0073],
#                       [ 0.0094, -0.0035,  0.0056,  ...,  0.0157,  0.0066,  0.0142],
#                       [ 0.0005,  0.0041,  0.0170,  ...,  0.0190,  0.0077, -0.0076],
#                       ...,
#                       [-0.0130, -0.0053, -0.0029,  ...,  0.0130,  0.0151, -0.0096],
#                       [ 0.0047,  0.0001,  0.0059,  ..., -0.0135,  0.0076,  0.0034],
#                       [-0.0068,  0.0094,  0.0088,  ..., -0.0050, -0.0071,  0.0043]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.8.attention.dense.bias',
#               tensor([ 0.0025, -0.0024,  0.0014,  ..., -0.0030,  0.0064,  0.0024],
#                      device='cuda:0')),
#              ('gpt_neox.layers.8.mlp.dense_h_to_4h.weight',
#               tensor([[-0.0175, -0.0274, -0.0079,  ...,  0.0123,  0.0034, -0.0331],
#                       [ 0.0558, -0.0475, -0.0135,  ..., -0.0154, -0.0087, -0.0070],
#                       [-0.0208,  0.0149, -0.0289,  ...,  0.0415, -0.0037,  0.0125],
#                       ...,
#                       [ 0.0365, -0.0071,  0.0307,  ..., -0.0190,  0.0010,  0.0093],
#                       [ 0.0026, -0.0374, -0.0073,  ...,  0.0072, -0.0294, -0.0288],
#                       [ 0.0012, -0.0204, -0.0204,  ..., -0.0081, -0.0102, -0.0179]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.8.mlp.dense_h_to_4h.bias',
#               tensor([-0.0084, -0.0086, -0.0055,  ..., -0.0066, -0.0055, -0.0093],
#                      device='cuda:0')),
#              ('gpt_neox.layers.8.mlp.dense_4h_to_h.weight',
#               tensor([[-3.9024e-03,  1.9569e-03, -1.8173e-02,  ..., -1.3908e-02,
#                         1.1810e-02,  8.8272e-03],
#                       [-5.8556e-03,  8.5449e-03,  1.9302e-02,  ...,  1.9417e-03,
#                        -6.3858e-03,  4.3755e-03],
#                       [-1.0519e-03, -1.2207e-02,  2.3079e-03,  ...,  6.9084e-03,
#                         2.4021e-04,  7.4539e-03],
#                       ...,
#                       [-1.2169e-02, -7.4625e-05, -6.2752e-03,  ...,  1.0994e-02,
#                        -1.1604e-02, -2.9697e-03],
#                       [ 8.4534e-03,  2.7103e-03, -5.1956e-03,  ..., -7.2517e-03,
#                         1.5808e-02,  5.4283e-03],
#                       [-7.8354e-03, -4.0932e-03,  2.0035e-02,  ...,  3.6659e-03,
#                        -1.0178e-02,  5.0621e-03]], device='cuda:0')),
#              ('gpt_neox.layers.8.mlp.dense_4h_to_h.bias',
#               tensor([ 0.0025, -0.0024,  0.0014,  ..., -0.0030,  0.0064,  0.0024],
#                      device='cuda:0')),
#              ('gpt_neox.layers.9.input_layernorm.weight',
#               tensor([1.0107, 1.0098, 1.0225,  ..., 1.0049, 1.0186, 1.0176], device='cuda:0')),
#              ('gpt_neox.layers.9.input_layernorm.bias',
#               tensor([ 0.0006,  0.0021, -0.0023,  ...,  0.0037, -0.0034, -0.0044],
#                      device='cuda:0')),
#              ('gpt_neox.layers.9.post_attention_layernorm.weight',
#               tensor([1.1055, 1.1113, 1.0996,  ..., 1.1377, 1.1055, 1.1055], device='cuda:0')),
#              ('gpt_neox.layers.9.post_attention_layernorm.bias',
#               tensor([ 0.0407,  0.0229,  0.0219,  ..., -0.0435,  0.0289,  0.0076],
#                      device='cuda:0')),
#              ('gpt_neox.layers.9.attention.rotary_emb.inv_freq',
#               tensor([1.0000e+00, 3.1616e-01, 9.9976e-02, 3.1616e-02, 1.0002e-02, 3.1624e-03,
#                       1.0004e-03, 3.1614e-04], device='cuda:0')),
#              ('gpt_neox.layers.9.attention.query_key_value.weight',
#               tensor([[-0.0127,  0.0149, -0.0599,  ...,  0.0262,  0.0166,  0.0558],
#                       [ 0.0136, -0.0119, -0.0508,  ...,  0.0509,  0.0331, -0.0042],
#                       [ 0.0107, -0.0180, -0.0098,  ..., -0.0039,  0.0268,  0.0402],
#                       ...,
#                       [ 0.0136, -0.0159, -0.0096,  ..., -0.0196,  0.0047, -0.0023],
#                       [ 0.0412,  0.0161,  0.0026,  ...,  0.0009,  0.0108, -0.0229],
#                       [ 0.0442, -0.0609, -0.0030,  ..., -0.0062,  0.0257,  0.0123]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.9.attention.query_key_value.bias',
#               tensor([-0.0019,  0.0061,  0.0007,  ...,  0.0003,  0.0020, -0.0006],
#                      device='cuda:0')),
#              ('gpt_neox.layers.9.attention.dense.weight',
#               tensor([[ 0.0022,  0.0296,  0.0005,  ...,  0.0079,  0.0038,  0.0062],
#                       [-0.0062,  0.0015,  0.0058,  ...,  0.0110, -0.0039,  0.0238],
#                       [-0.0066,  0.0058,  0.0142,  ..., -0.0081,  0.0026, -0.0046],
#                       ...,
#                       [-0.0059, -0.0119, -0.0006,  ..., -0.0052,  0.0102, -0.0137],
#                       [ 0.0114,  0.0159, -0.0063,  ...,  0.0077, -0.0041, -0.0174],
#                       [-0.0064,  0.0036,  0.0100,  ...,  0.0071,  0.0108, -0.0139]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.9.attention.dense.bias',
#               tensor([ 0.0020, -0.0056,  0.0015,  ..., -0.0001,  0.0061,  0.0042],
#                      device='cuda:0')),
#              ('gpt_neox.layers.9.mlp.dense_h_to_4h.weight',
#               tensor([[ 4.7913e-02, -5.8838e-02,  3.4668e-02,  ..., -9.5844e-04,
#                        -1.5884e-02, -1.0498e-02],
#                       [ 1.9165e-02,  3.2997e-03, -2.4536e-02,  ..., -1.9424e-02,
#                         1.7975e-02,  1.4214e-02],
#                       [-2.9030e-03, -1.0498e-02, -9.2545e-03,  ...,  2.2476e-02,
#                         1.1292e-02, -8.0872e-03],
#                       ...,
#                       [-2.6108e-02, -4.2175e-02,  1.2962e-02,  ...,  3.8025e-02,
#                        -4.2633e-02,  2.3041e-02],
#                       [-1.4481e-02, -7.8964e-03,  7.5340e-03,  ...,  2.9583e-03,
#                         7.2837e-05,  3.3844e-02],
#                       [-1.5884e-02, -3.2005e-03,  1.7044e-02,  ..., -2.9087e-03,
#                         9.1782e-03, -5.2582e-02]], device='cuda:0')),
#              ('gpt_neox.layers.9.mlp.dense_h_to_4h.bias',
#               tensor([-0.0098, -0.0115, -0.0064,  ..., -0.0126, -0.0070, -0.0127],
#                      device='cuda:0')),
#              ('gpt_neox.layers.9.mlp.dense_4h_to_h.weight',
#               tensor([[-0.0061, -0.0109,  0.0018,  ...,  0.0069, -0.0031,  0.0007],
#                       [ 0.0061,  0.0085,  0.0024,  ..., -0.0047,  0.0039, -0.0038],
#                       [-0.0138, -0.0089,  0.0129,  ..., -0.0008, -0.0030, -0.0195],
#                       ...,
#                       [-0.0034, -0.0084,  0.0033,  ...,  0.0092,  0.0066,  0.0060],
#                       [-0.0062, -0.0244, -0.0026,  ...,  0.0006,  0.0075,  0.0084],
#                       [-0.0070, -0.0143, -0.0017,  ..., -0.0012, -0.0114,  0.0076]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.9.mlp.dense_4h_to_h.bias',
#               tensor([ 0.0020, -0.0056,  0.0015,  ..., -0.0001,  0.0061,  0.0042],
#                      device='cuda:0')),
#              ('gpt_neox.layers.10.input_layernorm.weight',
#               tensor([1.0020, 1.0127, 1.0059,  ..., 0.9966, 1.0098, 1.0117], device='cuda:0')),
#              ('gpt_neox.layers.10.input_layernorm.bias',
#               tensor([ 0.0004, -0.0062, -0.0084,  ...,  0.0085,  0.0079, -0.0039],
#                      device='cuda:0')),
#              ('gpt_neox.layers.10.post_attention_layernorm.weight',
#               tensor([1.1016, 1.1113, 1.0996,  ..., 1.1279, 1.0957, 1.1211], device='cuda:0')),
#              ('gpt_neox.layers.10.post_attention_layernorm.bias',
#               tensor([ 3.4332e-02, -1.1384e-05,  2.2324e-02,  ..., -3.3295e-02,
#                        1.8661e-02,  3.1891e-02], device='cuda:0')),
#              ('gpt_neox.layers.10.attention.rotary_emb.inv_freq',
#               tensor([1.0000e+00, 3.1616e-01, 9.9976e-02, 3.1616e-02, 1.0002e-02, 3.1624e-03,
#                       1.0004e-03, 3.1614e-04], device='cuda:0')),
#              ('gpt_neox.layers.10.attention.query_key_value.weight',
#               tensor([[ 4.8161e-05,  4.9896e-02,  9.5139e-03,  ...,  3.4599e-03,
#                         3.8025e-02, -3.8795e-03],
#                       [-3.6001e-04,  3.0975e-02, -2.4124e-02,  ...,  3.5934e-03,
#                         7.8857e-02,  2.1729e-02],
#                       [ 3.4851e-02,  2.6321e-02, -1.1223e-02,  ..., -4.1870e-02,
#                        -1.8295e-02,  1.2848e-02],
#                       ...,
#                       [-1.5793e-02, -1.6144e-02, -1.5717e-02,  ..., -8.9798e-03,
#                         7.4463e-03,  3.0334e-02],
#                       [ 9.4938e-04,  3.3417e-02, -1.2646e-03,  ..., -2.6840e-02,
#                        -2.3972e-02,  1.4908e-02],
#                       [-2.7409e-03, -1.6708e-02,  5.2673e-02,  ...,  1.9104e-02,
#                        -1.3710e-02, -1.9852e-02]], device='cuda:0')),
#              ('gpt_neox.layers.10.attention.query_key_value.bias',
#               tensor([ 4.1084e-03,  9.2316e-03,  1.2646e-03,  ...,  2.2435e-04,
#                       -7.9572e-05,  4.1122e-03], device='cuda:0')),
#              ('gpt_neox.layers.10.attention.dense.weight',
#               tensor([[-4.1695e-03, -2.6169e-03,  5.7716e-03,  ...,  1.9007e-03,
#                        -3.7632e-03,  5.6219e-04],
#                       [ 1.4832e-02, -1.5976e-02,  6.1302e-03,  ..., -8.0566e-03,
#                        -1.2375e-02, -3.7632e-03],
#                       [ 1.0597e-02, -1.1072e-03, -1.6068e-02,  ...,  6.7139e-03,
#                         1.6270e-03, -4.6196e-03],
#                       ...,
#                       [-2.3315e-02,  1.7456e-02, -4.3392e-04,  ..., -1.2290e-04,
#                         1.4221e-02, -7.9572e-05],
#                       [ 2.8152e-03,  1.1463e-03, -9.9335e-03,  ...,  3.4523e-03,
#                        -2.1629e-03, -3.9062e-03],
#                       [-1.0080e-03,  3.2902e-03, -1.8951e-02,  ..., -1.5564e-02,
#                         8.5526e-03,  2.1672e-04]], device='cuda:0')),
#              ('gpt_neox.layers.10.attention.dense.bias',
#               tensor([ 0.0012, -0.0052,  0.0020,  ...,  0.0002,  0.0046,  0.0026],
#                      device='cuda:0')),
#              ('gpt_neox.layers.10.mlp.dense_h_to_4h.weight',
#               tensor([[-0.0277,  0.0059, -0.0121,  ..., -0.0202, -0.0189,  0.0102],
#                       [ 0.0176, -0.0038, -0.0323,  ..., -0.0263, -0.0395,  0.0074],
#                       [-0.0119,  0.0116, -0.0325,  ..., -0.0124, -0.0374,  0.0142],
#                       ...,
#                       [-0.0233, -0.0100, -0.0138,  ..., -0.0104, -0.0079, -0.0626],
#                       [ 0.0165, -0.0181,  0.0211,  ...,  0.0238,  0.0216,  0.0529],
#                       [ 0.0378, -0.0122, -0.0114,  ...,  0.0583, -0.0169, -0.0558]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.10.mlp.dense_h_to_4h.bias',
#               tensor([-0.0030, -0.0038, -0.0062,  ..., -0.0092, -0.0129, -0.0074],
#                      device='cuda:0')),
#              ('gpt_neox.layers.10.mlp.dense_4h_to_h.weight',
#               tensor([[-2.6283e-03,  6.1226e-03, -5.5504e-03,  ..., -1.4000e-02,
#                        -9.9182e-03, -1.6272e-05],
#                       [-6.0310e-03, -7.8964e-03,  1.4238e-03,  ..., -1.0017e-02,
#                        -2.3842e-03,  1.9913e-02],
#                       [-6.0196e-03,  8.5754e-03,  3.8767e-04,  ..., -4.7989e-03,
# ...
#                       [-0.0070,  0.0041, -0.0262,  ..., -0.0073,  0.0083, -0.0034]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.20.attention.dense.bias',
#               tensor([ 0.0016, -0.0044,  0.0006,  ...,  0.0047,  0.0040,  0.0019],
#                      device='cuda:0')),
#              ('gpt_neox.layers.20.mlp.dense_h_to_4h.weight',
#               tensor([[ 0.0126,  0.0268,  0.0045,  ...,  0.0166,  0.0581,  0.0269],
#                       [ 0.0070, -0.0009, -0.0227,  ...,  0.0010,  0.0081, -0.0252],
#                       [ 0.0039, -0.0439, -0.0616,  ..., -0.0356,  0.0311, -0.0214],
#                       ...,
#                       [ 0.0006,  0.0083, -0.0264,  ...,  0.0073, -0.0279,  0.0006],
#                       [ 0.0314,  0.0016,  0.0076,  ...,  0.0060, -0.0164, -0.0128],
#                       [ 0.0220,  0.0165, -0.0594,  ..., -0.0041, -0.0576, -0.0345]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.20.mlp.dense_h_to_4h.bias',
#               tensor([-0.0035, -0.0102, -0.0042,  ..., -0.0136, -0.0035, -0.0038],
#                      device='cuda:0')),
#              ('gpt_neox.layers.20.mlp.dense_4h_to_h.weight',
#               tensor([[-0.0103, -0.0065, -0.0001,  ..., -0.0135, -0.0051, -0.0041],
#                       [-0.0104, -0.0075,  0.0057,  ...,  0.0003,  0.0032,  0.0020],
#                       [-0.0031,  0.0079, -0.0062,  ..., -0.0008,  0.0098,  0.0089],
#                       ...,
#                       [-0.0065,  0.0046, -0.0341,  ...,  0.0106, -0.0104,  0.0007],
#                       [ 0.0053,  0.0075,  0.0103,  ...,  0.0023,  0.0104,  0.0006],
#                       [ 0.0126, -0.0111, -0.0018,  ...,  0.0134,  0.0083, -0.0026]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.20.mlp.dense_4h_to_h.bias',
#               tensor([ 0.0016, -0.0044,  0.0006,  ...,  0.0047,  0.0040,  0.0019],
#                      device='cuda:0')),
#              ('gpt_neox.layers.21.input_layernorm.weight',
#               tensor([1.0254, 1.0254, 1.0234,  ..., 1.0225, 1.0254, 1.0166], device='cuda:0')),
#              ('gpt_neox.layers.21.input_layernorm.bias',
#               tensor([ 0.0045, -0.0085, -0.0032,  ...,  0.0123,  0.0135,  0.0056],
#                      device='cuda:0')),
#              ('gpt_neox.layers.21.post_attention_layernorm.weight',
#               tensor([1.1104, 1.1143, 1.0898,  ..., 1.1318, 1.1113, 1.0889], device='cuda:0')),
#              ('gpt_neox.layers.21.post_attention_layernorm.bias',
#               tensor([ 0.0170, -0.0173,  0.0154,  ..., -0.0022,  0.0135,  0.0193],
#                      device='cuda:0')),
#              ('gpt_neox.layers.21.attention.rotary_emb.inv_freq',
#               tensor([1.0000e+00, 3.1616e-01, 9.9976e-02, 3.1616e-02, 1.0002e-02, 3.1624e-03,
#                       1.0004e-03, 3.1614e-04], device='cuda:0')),
#              ('gpt_neox.layers.21.attention.query_key_value.weight',
#               tensor([[ 0.0099,  0.0430,  0.0055,  ..., -0.0245, -0.0193,  0.0462],
#                       [ 0.0201,  0.0121, -0.0210,  ...,  0.0019, -0.0151,  0.0356],
#                       [-0.0341,  0.0124, -0.0081,  ...,  0.0264, -0.0240,  0.0217],
#                       ...,
#                       [ 0.0478, -0.0420, -0.0201,  ..., -0.0031, -0.0240,  0.0254],
#                       [ 0.0198, -0.0209, -0.0142,  ...,  0.0440, -0.0020, -0.0071],
#                       [-0.0050,  0.0262, -0.0158,  ...,  0.0112,  0.0180,  0.0284]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.21.attention.query_key_value.bias',
#               tensor([ 0.0012, -0.0010,  0.0040,  ...,  0.0011, -0.0021, -0.0006],
#                      device='cuda:0')),
#              ('gpt_neox.layers.21.attention.dense.weight',
#               tensor([[-0.0026, -0.0068,  0.0088,  ..., -0.0008, -0.0026,  0.0021],
#                       [ 0.0129, -0.0030, -0.0118,  ...,  0.0012, -0.0125,  0.0091],
#                       [-0.0009,  0.0249,  0.0114,  ...,  0.0054, -0.0042,  0.0174],
#                       ...,
#                       [-0.0007,  0.0015, -0.0087,  ...,  0.0064, -0.0114,  0.0009],
#                       [ 0.0052,  0.0164, -0.0014,  ...,  0.0003, -0.0065,  0.0027],
#                       [-0.0110, -0.0071,  0.0191,  ..., -0.0021,  0.0145,  0.0072]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.21.attention.dense.bias',
#               tensor([ 0.0003, -0.0020,  0.0012,  ...,  0.0046,  0.0030, -0.0014],
#                      device='cuda:0')),
#              ('gpt_neox.layers.21.mlp.dense_h_to_4h.weight',
#               tensor([[ 0.0239, -0.0057, -0.0063,  ..., -0.0380, -0.0270,  0.0364],
#                       [ 0.0103, -0.0463,  0.0161,  ...,  0.0266, -0.0056, -0.0309],
#                       [-0.0549, -0.0101, -0.0071,  ...,  0.0326, -0.0520,  0.0224],
#                       ...,
#                       [ 0.0031, -0.0027,  0.0171,  ...,  0.0070, -0.0258, -0.0461],
#                       [-0.0066,  0.0338,  0.0058,  ...,  0.0256, -0.0108, -0.0365],
#                       [ 0.0320,  0.0056, -0.0159,  ..., -0.0027, -0.0469, -0.0284]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.21.mlp.dense_h_to_4h.bias',
#               tensor([-0.0052, -0.0010, -0.0019,  ..., -0.0038, -0.0046, -0.0032],
#                      device='cuda:0')),
#              ('gpt_neox.layers.21.mlp.dense_4h_to_h.weight',
#               tensor([[-0.0081, -0.0019,  0.0112,  ...,  0.0115, -0.0104, -0.0069],
#                       [ 0.0066,  0.0152, -0.0253,  ...,  0.0041, -0.0047,  0.0151],
#                       [ 0.0079, -0.0122, -0.0129,  ...,  0.0077,  0.0131, -0.0118],
#                       ...,
#                       [-0.0088,  0.0074,  0.0060,  ..., -0.0095, -0.0041, -0.0127],
#                       [-0.0162,  0.0111,  0.0190,  ...,  0.0006,  0.0087,  0.0065],
#                       [-0.0208, -0.0121, -0.0028,  ..., -0.0056, -0.0014, -0.0040]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.21.mlp.dense_4h_to_h.bias',
#               tensor([ 0.0003, -0.0020,  0.0012,  ...,  0.0046,  0.0030, -0.0014],
#                      device='cuda:0')),
#              ('gpt_neox.layers.22.input_layernorm.weight',
#               tensor([1.0088, 1.0117, 1.0088,  ..., 1.0156, 1.0195, 1.0059], device='cuda:0')),
#              ('gpt_neox.layers.22.input_layernorm.bias',
#               tensor([ 0.0035, -0.0049, -0.0027,  ...,  0.0091,  0.0121,  0.0059],
#                      device='cuda:0')),
#              ('gpt_neox.layers.22.post_attention_layernorm.weight',
#               tensor([1.0977, 1.1152, 1.1045,  ..., 1.1104, 1.0938, 1.0830], device='cuda:0')),
#              ('gpt_neox.layers.22.post_attention_layernorm.bias',
#               tensor([ 0.0055, -0.0137,  0.0108,  ...,  0.0046,  0.0076,  0.0127],
#                      device='cuda:0')),
#              ('gpt_neox.layers.22.attention.rotary_emb.inv_freq',
#               tensor([1.0000e+00, 3.1616e-01, 9.9976e-02, 3.1616e-02, 1.0002e-02, 3.1624e-03,
#                       1.0004e-03, 3.1614e-04], device='cuda:0')),
#              ('gpt_neox.layers.22.attention.query_key_value.weight',
#               tensor([[ 0.0091, -0.0205, -0.0263,  ...,  0.0350,  0.0588,  0.0467],
#                       [ 0.0114, -0.0281, -0.0168,  ..., -0.0140,  0.0092,  0.0027],
#                       [-0.0061,  0.0396, -0.0209,  ..., -0.0222, -0.0108,  0.0237],
#                       ...,
#                       [ 0.0220, -0.0520, -0.0245,  ..., -0.0262, -0.0137, -0.0075],
#                       [ 0.0278, -0.0251, -0.0068,  ..., -0.0128, -0.0297,  0.0203],
#                       [-0.0236,  0.0350,  0.0095,  ..., -0.0098,  0.0580,  0.0255]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.22.attention.query_key_value.bias',
#               tensor([ 0.0153,  0.0118, -0.0094,  ..., -0.0030, -0.0016,  0.0011],
#                      device='cuda:0')),
#              ('gpt_neox.layers.22.attention.dense.weight',
#               tensor([[ 0.0140, -0.0013, -0.0020,  ..., -0.0018,  0.0076, -0.0043],
#                       [-0.0015, -0.0064, -0.0053,  ...,  0.0052, -0.0020,  0.0057],
#                       [ 0.0085,  0.0010, -0.0036,  ..., -0.0045,  0.0099, -0.0034],
#                       ...,
#                       [-0.0065, -0.0185, -0.0018,  ..., -0.0108, -0.0131, -0.0007],
#                       [ 0.0037,  0.0074,  0.0086,  ...,  0.0111, -0.0017, -0.0071],
#                       [ 0.0032,  0.0101,  0.0084,  ...,  0.0021,  0.0146, -0.0013]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.22.attention.dense.bias',
#               tensor([-4.5133e-04, -1.0109e-04, -4.2379e-05,  ...,  3.6087e-03,
#                        1.0452e-03, -3.3703e-03], device='cuda:0')),
#              ('gpt_neox.layers.22.mlp.dense_h_to_4h.weight',
#               tensor([[ 0.0031, -0.0353, -0.0029,  ..., -0.0137,  0.0234,  0.0041],
#                       [-0.0095,  0.0383,  0.0140,  ..., -0.0470,  0.0035, -0.0212],
#                       [ 0.0047, -0.0144, -0.0415,  ..., -0.0239, -0.0029,  0.0255],
#                       ...,
#                       [-0.0062,  0.0187, -0.0251,  ...,  0.0011, -0.0019, -0.0004],
#                       [ 0.0388,  0.0219,  0.0355,  ...,  0.0172,  0.0006, -0.0104],
#                       [ 0.0158,  0.0294,  0.0045,  ...,  0.0219, -0.0160, -0.0021]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.22.mlp.dense_h_to_4h.bias',
#               tensor([-0.0053, -0.0086, -0.0030,  ..., -0.0054, -0.0029, -0.0046],
#                      device='cuda:0')),
#              ('gpt_neox.layers.22.mlp.dense_4h_to_h.weight',
#               tensor([[-8.9931e-04,  3.3069e-04, -1.8463e-03,  ..., -1.7944e-02,
#                        -3.9005e-03,  1.6495e-02],
#                       [-3.4523e-03,  2.9793e-03,  2.8954e-03,  ..., -9.0485e-03,
#                        -4.3411e-03, -1.7715e-02],
#                       [ 9.3613e-03,  1.9760e-02,  2.9984e-03,  ..., -1.0773e-02,
#                        -3.6669e-04,  5.0697e-03],
#                       ...,
#                       [-2.8572e-03,  2.6970e-03,  6.5002e-03,  ...,  4.3526e-03,
#                        -2.4612e-02, -6.7024e-03],
#                       [-1.7471e-02,  1.2886e-02,  5.8556e-03,  ...,  6.1646e-03,
#                         5.3823e-05, -7.4730e-03],
#                       [-7.2784e-03,  1.5182e-02, -7.4425e-03,  ...,  3.3951e-03,
#                        -6.4964e-03, -1.2379e-03]], device='cuda:0')),
#              ('gpt_neox.layers.22.mlp.dense_4h_to_h.bias',
#               tensor([-4.5133e-04, -1.0109e-04, -4.2379e-05,  ...,  3.6087e-03,
#                        1.0452e-03, -3.3703e-03], device='cuda:0')),
#              ('gpt_neox.layers.23.input_layernorm.weight',
#               tensor([1.0059, 1.0107, 1.0234,  ..., 1.0068, 1.0156, 1.0107], device='cuda:0')),
#              ('gpt_neox.layers.23.input_layernorm.bias',
#               tensor([ 0.0016, -0.0006, -0.0039,  ...,  0.0094,  0.0099, -0.0053],
#                      device='cuda:0')),
#              ('gpt_neox.layers.23.post_attention_layernorm.weight',
#               tensor([1.0352, 1.0547, 1.0352,  ..., 1.0566, 1.0459, 1.0430], device='cuda:0')),
#              ('gpt_neox.layers.23.post_attention_layernorm.bias',
#               tensor([-0.0028,  0.0005,  0.0027,  ..., -0.0015, -0.0024,  0.0038],
#                      device='cuda:0')),
#              ('gpt_neox.layers.23.attention.rotary_emb.inv_freq',
#               tensor([1.0000e+00, 3.1616e-01, 9.9976e-02, 3.1616e-02, 1.0002e-02, 3.1624e-03,
#                       1.0004e-03, 3.1614e-04], device='cuda:0')),
#              ('gpt_neox.layers.23.attention.query_key_value.weight',
#               tensor([[-0.0130,  0.0025, -0.0151,  ...,  0.0042,  0.0249, -0.0213],
#                       [ 0.0018,  0.0262, -0.0116,  ...,  0.0092,  0.0103, -0.0391],
#                       [ 0.0074, -0.0479, -0.0310,  ...,  0.0208, -0.0152,  0.0123],
#                       ...,
#                       [ 0.0067,  0.0114,  0.0187,  ..., -0.0186,  0.0168, -0.0184],
#                       [-0.0144,  0.0244, -0.0026,  ..., -0.0020,  0.0018, -0.0015],
#                       [-0.0044, -0.0021,  0.0319,  ...,  0.0381, -0.0230, -0.0226]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.23.attention.query_key_value.bias',
#               tensor([ 0.0035,  0.0036, -0.0090,  ..., -0.0047,  0.0007, -0.0022],
#                      device='cuda:0')),
#              ('gpt_neox.layers.23.attention.dense.weight',
#               tensor([[ 0.0205,  0.0013, -0.0001,  ..., -0.0007, -0.0031,  0.0069],
#                       [-0.0022,  0.0066,  0.0038,  ...,  0.0013,  0.0024, -0.0022],
#                       [ 0.0091, -0.0005, -0.0035,  ..., -0.0027, -0.0149,  0.0004],
#                       ...,
#                       [-0.0029,  0.0137,  0.0031,  ...,  0.0045,  0.0098, -0.0010],
#                       [ 0.0001,  0.0062, -0.0053,  ...,  0.0008,  0.0070,  0.0042],
#                       [ 0.0155,  0.0022, -0.0116,  ...,  0.0022, -0.0069, -0.0085]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.23.attention.dense.bias',
#               tensor([ 0.0020, -0.0014, -0.0014,  ...,  0.0026,  0.0009, -0.0047],
#                      device='cuda:0')),
#              ('gpt_neox.layers.23.mlp.dense_h_to_4h.weight',
#               tensor([[-0.0140,  0.0066, -0.0431,  ...,  0.0464, -0.0139,  0.0092],
#                       [-0.0199,  0.0117,  0.0202,  ..., -0.0287,  0.0326,  0.0191],
#                       [-0.0003,  0.0008, -0.0407,  ..., -0.0086,  0.0217, -0.0052],
#                       ...,
#                       [-0.0345,  0.0589,  0.0180,  ...,  0.0070,  0.0130,  0.0092],
#                       [-0.0185, -0.0092,  0.0016,  ..., -0.0093, -0.0309, -0.0323],
#                       [-0.0031, -0.0070,  0.0065,  ..., -0.0172, -0.0091, -0.0601]],
#                      device='cuda:0')),
#              ('gpt_neox.layers.23.mlp.dense_h_to_4h.bias',
#               tensor([-0.0038, -0.0044, -0.0048,  ..., -0.0088, -0.0037, -0.0005],
#                      device='cuda:0')),
#              ('gpt_neox.layers.23.mlp.dense_4h_to_h.weight',
#               tensor([[-7.1411e-03, -8.8501e-03,  1.4534e-02,  ..., -9.0714e-03,
#                        -1.9627e-03, -9.0408e-03],
#                       [ 8.4076e-03, -4.4136e-03,  8.8501e-04,  ...,  9.4366e-04,
#                         9.7046e-03,  2.0790e-03],
#                       [-1.3145e-02,  2.1011e-02, -1.2001e-02,  ...,  3.8643e-03,
#                        -2.8973e-03,  1.0269e-02],
#                       ...,
#                       [-1.4145e-02,  9.9335e-03,  2.0020e-02,  ...,  1.8799e-02,
#                         1.2665e-02,  8.7547e-04],
#                       [-3.9787e-03, -5.9280e-03,  1.6586e-02,  ...,  1.9028e-02,
#                         1.1702e-03,  1.4145e-02],
#                       [-1.8759e-03,  5.7817e-05, -1.4603e-02,  ..., -3.5229e-03,
#                        -2.5742e-02,  1.8368e-03]], device='cuda:0')),
#              ('gpt_neox.layers.23.mlp.dense_4h_to_h.bias',
#               tensor([ 0.0020, -0.0014, -0.0014,  ...,  0.0026,  0.0009, -0.0047],
#                      device='cuda:0')),
#              ('gpt_neox.final_layer_norm.weight',
#               tensor([1.4404, 1.3545, 1.4443,  ..., 1.4414, 1.3945, 1.4678], device='cuda:0')),
#              ('gpt_neox.final_layer_norm.bias',
#               tensor([ 0.0733, -0.0663,  0.0184,  ...,  0.0640,  0.0799,  0.0401],
#                      device='cuda:0')),
#              ('embed_out.weight',
#               tensor([[ 0.0189,  0.0612, -0.0076,  ..., -0.0071, -0.0212,  0.0163],
#                       [ 0.0016,  0.0144, -0.0015,  ...,  0.0002, -0.0499, -0.0299],
#                       [ 0.0133,  0.0120,  0.0080,  ..., -0.0091,  0.0109,  0.0003],
#                       ...,
#                       [-0.0340,  0.0199, -0.0118,  ..., -0.0410, -0.0105,  0.0149],
#                       [-0.0198,  0.0213, -0.0159,  ..., -0.0087, -0.0118, -0.0158],
#                       [-0.0006,  0.0302, -0.0014,  ..., -0.0196, -0.0484, -0.0076]],
#                      device='cuda:0'))])

# %%
# are layernorms being loaded in correctly?
model.eval()
for k, v in model.state_dict().items():
    print('%.4f %s' % (v.sum(), k))
# Out:
# 146.9542 gpt_neox.embed_in.weight
# 1037.7881 gpt_neox.layers.0.input_layernorm.weight
# -0.2250 gpt_neox.layers.0.input_layernorm.bias
# 999.5356 gpt_neox.layers.0.post_attention_layernorm.weight
# 0.0468 gpt_neox.layers.0.post_attention_layernorm.bias
# 1.4622 gpt_neox.layers.0.attention.rotary_emb.inv_freq
# 2.7440 gpt_neox.layers.0.attention.query_key_value.weight
# 7.8361 gpt_neox.layers.0.attention.query_key_value.bias
# -0.6809 gpt_neox.layers.0.attention.dense.weight
# 0.0034 gpt_neox.layers.0.attention.dense.bias
# -16.9326 gpt_neox.layers.0.mlp.dense_h_to_4h.weight
# -42.5715 gpt_neox.layers.0.mlp.dense_h_to_4h.bias
# 16.7741 gpt_neox.layers.0.mlp.dense_4h_to_h.weight
# 0.0034 gpt_neox.layers.0.mlp.dense_4h_to_h.bias
# 1031.0425 gpt_neox.layers.1.input_layernorm.weight
# -0.0388 gpt_neox.layers.1.input_layernorm.bias
# 1055.9355 gpt_neox.layers.1.post_attention_layernorm.weight
# 0.3230 gpt_neox.layers.1.post_attention_layernorm.bias
# 1.4622 gpt_neox.layers.1.attention.rotary_emb.inv_freq
# -7.4484 gpt_neox.layers.1.attention.query_key_value.weight
# 5.7139 gpt_neox.layers.1.attention.query_key_value.bias
# 2.7544 gpt_neox.layers.1.attention.dense.weight
# -0.0099 gpt_neox.layers.1.attention.dense.bias
# -166.0288 gpt_neox.layers.1.mlp.dense_h_to_4h.weight
# -27.0767 gpt_neox.layers.1.mlp.dense_h_to_4h.bias
# 17.8220 gpt_neox.layers.1.mlp.dense_4h_to_h.weight
# -0.0099 gpt_neox.layers.1.mlp.dense_4h_to_h.bias
# 993.9629 gpt_neox.layers.2.input_layernorm.weight
# 0.0968 gpt_neox.layers.2.input_layernorm.bias
# 1083.4238 gpt_neox.layers.2.post_attention_layernorm.weight
# 0.1185 gpt_neox.layers.2.post_attention_layernorm.bias
# 1.4622 gpt_neox.layers.2.attention.rotary_emb.inv_freq
# -54.2171 gpt_neox.layers.2.attention.query_key_value.weight
# -2.0122 gpt_neox.layers.2.attention.query_key_value.bias
# 1.9931 gpt_neox.layers.2.attention.dense.weight
# -0.0132 gpt_neox.layers.2.attention.dense.bias
# -132.8870 gpt_neox.layers.2.mlp.dense_h_to_4h.weight
# -35.2620 gpt_neox.layers.2.mlp.dense_h_to_4h.bias
# -3.6120 gpt_neox.layers.2.mlp.dense_4h_to_h.weight
# -0.0132 gpt_neox.layers.2.mlp.dense_4h_to_h.bias
# 995.2217 gpt_neox.layers.3.input_layernorm.weight
# 0.0259 gpt_neox.layers.3.input_layernorm.bias
# 1095.8984 gpt_neox.layers.3.post_attention_layernorm.weight
# 0.0533 gpt_neox.layers.3.post_attention_layernorm.bias
# 1.4622 gpt_neox.layers.3.attention.rotary_emb.inv_freq
# -70.0234 gpt_neox.layers.3.attention.query_key_value.weight
# -0.1889 gpt_neox.layers.3.attention.query_key_value.bias
# 1.1129 gpt_neox.layers.3.attention.dense.weight
# -0.0090 gpt_neox.layers.3.attention.dense.bias
# -113.1621 gpt_neox.layers.3.mlp.dense_h_to_4h.weight
# -34.3567 gpt_neox.layers.3.mlp.dense_h_to_4h.bias
# -14.5649 gpt_neox.layers.3.mlp.dense_4h_to_h.weight
# -0.0090 gpt_neox.layers.3.mlp.dense_4h_to_h.bias
# 1001.7031 gpt_neox.layers.4.input_layernorm.weight
# -0.1774 gpt_neox.layers.4.input_layernorm.bias
# 1107.3340 gpt_neox.layers.4.post_attention_layernorm.weight
# 0.3840 gpt_neox.layers.4.post_attention_layernorm.bias
# 1.4622 gpt_neox.layers.4.attention.rotary_emb.inv_freq
# -8.6414 gpt_neox.layers.4.attention.query_key_value.weight
# -1.2989 gpt_neox.layers.4.attention.query_key_value.bias
# -2.1267 gpt_neox.layers.4.attention.dense.weight
# -0.0043 gpt_neox.layers.4.attention.dense.bias
# -191.1967 gpt_neox.layers.4.mlp.dense_h_to_4h.weight
# -34.0038 gpt_neox.layers.4.mlp.dense_h_to_4h.bias
# -26.5555 gpt_neox.layers.4.mlp.dense_4h_to_h.weight
# -0.0043 gpt_neox.layers.4.mlp.dense_4h_to_h.bias
# 1010.2578 gpt_neox.layers.5.input_layernorm.weight
# -0.2983 gpt_neox.layers.5.input_layernorm.bias
# 1119.3359 gpt_neox.layers.5.post_attention_layernorm.weight
# 0.3895 gpt_neox.layers.5.post_attention_layernorm.bias
# 1.4622 gpt_neox.layers.5.attention.rotary_emb.inv_freq
# -37.2699 gpt_neox.layers.5.attention.query_key_value.weight
# -0.7944 gpt_neox.layers.5.attention.query_key_value.bias
# -7.8035 gpt_neox.layers.5.attention.dense.weight
# 0.0019 gpt_neox.layers.5.attention.dense.bias
# -198.5939 gpt_neox.layers.5.mlp.dense_h_to_4h.weight
# -36.0767 gpt_neox.layers.5.mlp.dense_h_to_4h.bias
# -9.2536 gpt_neox.layers.5.mlp.dense_4h_to_h.weight
# 0.0019 gpt_neox.layers.5.mlp.dense_4h_to_h.bias
# 1016.0156 gpt_neox.layers.6.input_layernorm.weight
# -0.1118 gpt_neox.layers.6.input_layernorm.bias
# 1122.3750 gpt_neox.layers.6.post_attention_layernorm.weight
# 0.6280 gpt_neox.layers.6.post_attention_layernorm.bias
# 1.4622 gpt_neox.layers.6.attention.rotary_emb.inv_freq
# -12.2511 gpt_neox.layers.6.attention.query_key_value.weight
# 0.8780 gpt_neox.layers.6.attention.query_key_value.bias
# 4.1289 gpt_neox.layers.6.attention.dense.weight
# 0.0028 gpt_neox.layers.6.attention.dense.bias
# -289.8854 gpt_neox.layers.6.mlp.dense_h_to_4h.weight
# -36.6511 gpt_neox.layers.6.mlp.dense_h_to_4h.bias
# -12.5445 gpt_neox.layers.6.mlp.dense_4h_to_h.weight
# 0.0028 gpt_neox.layers.6.mlp.dense_4h_to_h.bias
# 1019.9834 gpt_neox.layers.7.input_layernorm.weight
# -0.1154 gpt_neox.layers.7.input_layernorm.bias
# 1128.2871 gpt_neox.layers.7.post_attention_layernorm.weight
# 0.3870 gpt_neox.layers.7.post_attention_layernorm.bias
# 1.4622 gpt_neox.layers.7.attention.rotary_emb.inv_freq
# -7.5357 gpt_neox.layers.7.attention.query_key_value.weight
# -0.9187 gpt_neox.layers.7.attention.query_key_value.bias
# 0.5761 gpt_neox.layers.7.attention.dense.weight
# 0.0026 gpt_neox.layers.7.attention.dense.bias
# -251.4297 gpt_neox.layers.7.mlp.dense_h_to_4h.weight
# -35.8910 gpt_neox.layers.7.mlp.dense_h_to_4h.bias
# -39.0787 gpt_neox.layers.7.mlp.dense_4h_to_h.weight
# 0.0026 gpt_neox.layers.7.mlp.dense_4h_to_h.bias
# 1026.7378 gpt_neox.layers.8.input_layernorm.weight
# -0.0944 gpt_neox.layers.8.input_layernorm.bias
# 1130.0752 gpt_neox.layers.8.post_attention_layernorm.weight
# 0.2933 gpt_neox.layers.8.post_attention_layernorm.bias
# 1.4622 gpt_neox.layers.8.attention.rotary_emb.inv_freq
# -31.5738 gpt_neox.layers.8.attention.query_key_value.weight
# -0.5869 gpt_neox.layers.8.attention.query_key_value.bias
# -0.9458 gpt_neox.layers.8.attention.dense.weight
# 0.0011 gpt_neox.layers.8.attention.dense.bias
# -210.5584 gpt_neox.layers.8.mlp.dense_h_to_4h.weight
# -35.6391 gpt_neox.layers.8.mlp.dense_h_to_4h.bias
# -28.2160 gpt_neox.layers.8.mlp.dense_4h_to_h.weight
# 0.0011 gpt_neox.layers.8.mlp.dense_4h_to_h.bias
# 1037.4590 gpt_neox.layers.9.input_layernorm.weight
# 0.0399 gpt_neox.layers.9.input_layernorm.bias
# 1133.4619 gpt_neox.layers.9.post_attention_layernorm.weight
# 0.2254 gpt_neox.layers.9.post_attention_layernorm.bias
# 1.4622 gpt_neox.layers.9.attention.rotary_emb.inv_freq
# -18.8861 gpt_neox.layers.9.attention.query_key_value.weight
# -1.4150 gpt_neox.layers.9.attention.query_key_value.bias
# -0.2866 gpt_neox.layers.9.attention.dense.weight
# -0.0017 gpt_neox.layers.9.attention.dense.bias
# -140.8114 gpt_neox.layers.9.mlp.dense_h_to_4h.weight
# -37.2670 gpt_neox.layers.9.mlp.dense_h_to_4h.bias
# -26.0084 gpt_neox.layers.9.mlp.dense_4h_to_h.weight
# -0.0017 gpt_neox.layers.9.mlp.dense_4h_to_h.bias
# 1029.2441 gpt_neox.layers.10.input_layernorm.weight
# -0.1783 gpt_neox.layers.10.input_layernorm.bias
# 1137.2646 gpt_neox.layers.10.post_attention_layernorm.weight
# 0.2827 gpt_neox.layers.10.post_attention_layernorm.bias
# 1.4622 gpt_neox.layers.10.attention.rotary_emb.inv_freq
# -25.8714 gpt_neox.layers.10.attention.query_key_value.weight
# -1.7046 gpt_neox.layers.10.attention.query_key_value.bias
# -0.6594 gpt_neox.layers.10.attention.dense.weight
# -0.0101 gpt_neox.layers.10.attention.dense.bias
# -179.7714 gpt_neox.layers.10.mlp.dense_h_to_4h.weight
# -36.1914 gpt_neox.layers.10.mlp.dense_h_to_4h.bias
# -25.6701 gpt_neox.layers.10.mlp.dense_4h_to_h.weight
# -0.0101 gpt_neox.layers.10.mlp.dense_4h_to_h.bias
# 1044.8862 gpt_neox.layers.11.input_layernorm.weight
# 0.1371 gpt_neox.layers.11.input_layernorm.bias
# 1143.9531 gpt_neox.layers.11.post_attention_layernorm.weight
# 0.3948 gpt_neox.layers.11.post_attention_layernorm.bias
# 1.4622 gpt_neox.layers.11.attention.rotary_emb.inv_freq
# 5.2247 gpt_neox.layers.11.attention.query_key_value.weight
# -2.2127 gpt_neox.layers.11.attention.query_key_value.bias
# 2.6374 gpt_neox.layers.11.attention.dense.weight
# -0.0098 gpt_neox.layers.11.attention.dense.bias
# -98.4452 gpt_neox.layers.11.mlp.dense_h_to_4h.weight
# -37.8883 gpt_neox.layers.11.mlp.dense_h_to_4h.bias
# -26.6203 gpt_neox.layers.11.mlp.dense_4h_to_h.weight
# -0.0098 gpt_neox.layers.11.mlp.dense_4h_to_h.bias
# 1033.6685 gpt_neox.layers.12.input_layernorm.weight
# 0.0097 gpt_neox.layers.12.input_layernorm.bias
# 1143.0322 gpt_neox.layers.12.post_attention_layernorm.weight
# 0.1551 gpt_neox.layers.12.post_attention_layernorm.bias
# 1.4622 gpt_neox.layers.12.attention.rotary_emb.inv_freq
# -26.3892 gpt_neox.layers.12.attention.query_key_value.weight
# -0.4229 gpt_neox.layers.12.attention.query_key_value.bias
# 0.7403 gpt_neox.layers.12.attention.dense.weight
# -0.0047 gpt_neox.layers.12.attention.dense.bias
# -51.4532 gpt_neox.layers.12.mlp.dense_h_to_4h.weight
# -36.1181 gpt_neox.layers.12.mlp.dense_h_to_4h.bias
# -40.8660 gpt_neox.layers.12.mlp.dense_4h_to_h.weight
# -0.0047 gpt_neox.layers.12.mlp.dense_4h_to_h.bias
# 1049.4585 gpt_neox.layers.13.input_layernorm.weight
# 0.0361 gpt_neox.layers.13.input_layernorm.bias
# 1149.3252 gpt_neox.layers.13.post_attention_layernorm.weight
# 0.0752 gpt_neox.layers.13.post_attention_layernorm.bias
# 1.4622 gpt_neox.layers.13.attention.rotary_emb.inv_freq
# -49.8895 gpt_neox.layers.13.attention.query_key_value.weight
# 1.7637 gpt_neox.layers.13.attention.query_key_value.bias
# 3.8218 gpt_neox.layers.13.attention.dense.weight
# 0.0013 gpt_neox.layers.13.attention.dense.bias
# -15.3266 gpt_neox.layers.13.mlp.dense_h_to_4h.weight
# -35.9988 gpt_neox.layers.13.mlp.dense_h_to_4h.bias
# -24.7933 gpt_neox.layers.13.mlp.dense_4h_to_h.weight
# 0.0013 gpt_neox.layers.13.mlp.dense_4h_to_h.bias
# 1032.3057 gpt_neox.layers.14.input_layernorm.weight
# -0.0175 gpt_neox.layers.14.input_layernorm.bias
# 1151.9746 gpt_neox.layers.14.post_attention_layernorm.weight
# -0.5041 gpt_neox.layers.14.post_attention_layernorm.bias
# 1.4622 gpt_neox.layers.14.attention.rotary_emb.inv_freq
# 0.1943 gpt_neox.layers.14.attention.query_key_value.weight
# 3.1857 gpt_neox.layers.14.attention.query_key_value.bias
# -1.9651 gpt_neox.layers.14.attention.dense.weight
# 0.0011 gpt_neox.layers.14.attention.dense.bias
# 142.1689 gpt_neox.layers.14.mlp.dense_h_to_4h.weight
# -33.2992 gpt_neox.layers.14.mlp.dense_h_to_4h.bias
# -24.9390 gpt_neox.layers.14.mlp.dense_4h_to_h.weight
# 0.0011 gpt_neox.layers.14.mlp.dense_4h_to_h.bias
# 1034.4082 gpt_neox.layers.15.input_layernorm.weight
# 0.0966 gpt_neox.layers.15.input_layernorm.bias
# 1151.9141 gpt_neox.layers.15.post_attention_layernorm.weight
# -0.1025 gpt_neox.layers.15.post_attention_layernorm.bias
# 1.4622 gpt_neox.layers.15.attention.rotary_emb.inv_freq
# -8.4289 gpt_neox.layers.15.attention.query_key_value.weight
# 0.1017 gpt_neox.layers.15.attention.query_key_value.bias
# 3.9161 gpt_neox.layers.15.attention.dense.weight
# -0.0020 gpt_neox.layers.15.attention.dense.bias
# 75.8251 gpt_neox.layers.15.mlp.dense_h_to_4h.weight
# -32.5519 gpt_neox.layers.15.mlp.dense_h_to_4h.bias
# -22.6699 gpt_neox.layers.15.mlp.dense_4h_to_h.weight
# -0.0020 gpt_neox.layers.15.mlp.dense_4h_to_h.bias
# 1040.5854 gpt_neox.layers.16.input_layernorm.weight
# 0.1536 gpt_neox.layers.16.input_layernorm.bias
# 1151.1416 gpt_neox.layers.16.post_attention_layernorm.weight
# -0.0413 gpt_neox.layers.16.post_attention_layernorm.bias
# 1.4622 gpt_neox.layers.16.attention.rotary_emb.inv_freq
# -7.1268 gpt_neox.layers.16.attention.query_key_value.weight
# 1.2597 gpt_neox.layers.16.attention.query_key_value.bias
# -1.1939 gpt_neox.layers.16.attention.dense.weight
# 0.0048 gpt_neox.layers.16.attention.dense.bias
# 59.4035 gpt_neox.layers.16.mlp.dense_h_to_4h.weight
# -30.9783 gpt_neox.layers.16.mlp.dense_h_to_4h.bias
# -14.5130 gpt_neox.layers.16.mlp.dense_4h_to_h.weight
# 0.0048 gpt_neox.layers.16.mlp.dense_4h_to_h.bias
# 1045.6699 gpt_neox.layers.17.input_layernorm.weight
# -0.0445 gpt_neox.layers.17.input_layernorm.bias
# 1149.6562 gpt_neox.layers.17.post_attention_layernorm.weight
# 0.0459 gpt_neox.layers.17.post_attention_layernorm.bias
# 1.4622 gpt_neox.layers.17.attention.rotary_emb.inv_freq
# 38.9940 gpt_neox.layers.17.attention.query_key_value.weight
# 2.5747 gpt_neox.layers.17.attention.query_key_value.bias
# -3.7013 gpt_neox.layers.17.attention.dense.weight
# 0.0152 gpt_neox.layers.17.attention.dense.bias
# 45.6795 gpt_neox.layers.17.mlp.dense_h_to_4h.weight
# -29.9619 gpt_neox.layers.17.mlp.dense_h_to_4h.bias
# -15.5686 gpt_neox.layers.17.mlp.dense_4h_to_h.weight
# 0.0152 gpt_neox.layers.17.mlp.dense_4h_to_h.bias
# 1034.5513 gpt_neox.layers.18.input_layernorm.weight
# 0.0799 gpt_neox.layers.18.input_layernorm.bias
# 1145.9248 gpt_neox.layers.18.post_attention_layernorm.weight
# -0.0116 gpt_neox.layers.18.post_attention_layernorm.bias
# 1.4622 gpt_neox.layers.18.attention.rotary_emb.inv_freq
# 18.2484 gpt_neox.layers.18.attention.query_key_value.weight
# 0.1583 gpt_neox.layers.18.attention.query_key_value.bias
# -5.4925 gpt_neox.layers.18.attention.dense.weight
# 0.0146 gpt_neox.layers.18.attention.dense.bias
# 83.0484 gpt_neox.layers.18.mlp.dense_h_to_4h.weight
# -28.2866 gpt_neox.layers.18.mlp.dense_h_to_4h.bias
# -11.7604 gpt_neox.layers.18.mlp.dense_4h_to_h.weight
# 0.0146 gpt_neox.layers.18.mlp.dense_4h_to_h.bias
# 1042.5469 gpt_neox.layers.19.input_layernorm.weight
# 0.0689 gpt_neox.layers.19.input_layernorm.bias
# 1145.7324 gpt_neox.layers.19.post_attention_layernorm.weight
# -0.0297 gpt_neox.layers.19.post_attention_layernorm.bias
# 1.4622 gpt_neox.layers.19.attention.rotary_emb.inv_freq
# 60.4519 gpt_neox.layers.19.attention.query_key_value.weight
# -0.2424 gpt_neox.layers.19.attention.query_key_value.bias
# -4.6490 gpt_neox.layers.19.attention.dense.weight
# 0.0134 gpt_neox.layers.19.attention.dense.bias
# 43.7627 gpt_neox.layers.19.mlp.dense_h_to_4h.weight
# -26.9326 gpt_neox.layers.19.mlp.dense_h_to_4h.bias
# -10.3171 gpt_neox.layers.19.mlp.dense_4h_to_h.weight
# 0.0134 gpt_neox.layers.19.mlp.dense_4h_to_h.bias
# 1043.2979 gpt_neox.layers.20.input_layernorm.weight
# -0.0830 gpt_neox.layers.20.input_layernorm.bias
# 1139.6084 gpt_neox.layers.20.post_attention_layernorm.weight
# -0.1309 gpt_neox.layers.20.post_attention_layernorm.bias
# 1.4622 gpt_neox.layers.20.attention.rotary_emb.inv_freq
# 75.7636 gpt_neox.layers.20.attention.query_key_value.weight
# -2.9339 gpt_neox.layers.20.attention.query_key_value.bias
# 3.6527 gpt_neox.layers.20.attention.dense.weight
# 0.0127 gpt_neox.layers.20.attention.dense.bias
# 137.5879 gpt_neox.layers.20.mlp.dense_h_to_4h.weight
# -25.0640 gpt_neox.layers.20.mlp.dense_h_to_4h.bias
# 0.7946 gpt_neox.layers.20.mlp.dense_4h_to_h.weight
# 0.0127 gpt_neox.layers.20.mlp.dense_4h_to_h.bias
# 1054.2607 gpt_neox.layers.21.input_layernorm.weight
# -0.3664 gpt_neox.layers.21.input_layernorm.bias
# 1135.5762 gpt_neox.layers.21.post_attention_layernorm.weight
# -0.1074 gpt_neox.layers.21.post_attention_layernorm.bias
# 1.4622 gpt_neox.layers.21.attention.rotary_emb.inv_freq
# -28.3209 gpt_neox.layers.21.attention.query_key_value.weight
# 4.1720 gpt_neox.layers.21.attention.query_key_value.bias
# 3.5106 gpt_neox.layers.21.attention.dense.weight
# 0.0227 gpt_neox.layers.21.attention.dense.bias
# 52.7541 gpt_neox.layers.21.mlp.dense_h_to_4h.weight
# -23.4141 gpt_neox.layers.21.mlp.dense_h_to_4h.bias
# 3.4930 gpt_neox.layers.21.mlp.dense_4h_to_h.weight
# 0.0227 gpt_neox.layers.21.mlp.dense_4h_to_h.bias
# 1036.5693 gpt_neox.layers.22.input_layernorm.weight
# -0.0810 gpt_neox.layers.22.input_layernorm.bias
# 1123.9395 gpt_neox.layers.22.post_attention_layernorm.weight
# -0.0528 gpt_neox.layers.22.post_attention_layernorm.bias
# 1.4622 gpt_neox.layers.22.attention.rotary_emb.inv_freq
# -35.1234 gpt_neox.layers.22.attention.query_key_value.weight
# 2.5691 gpt_neox.layers.22.attention.query_key_value.bias
# 1.3437 gpt_neox.layers.22.attention.dense.weight
# 0.0215 gpt_neox.layers.22.attention.dense.bias
# 30.0167 gpt_neox.layers.22.mlp.dense_h_to_4h.weight
# -21.6412 gpt_neox.layers.22.mlp.dense_h_to_4h.bias
# -1.8805 gpt_neox.layers.22.mlp.dense_4h_to_h.weight
# 0.0215 gpt_neox.layers.22.mlp.dense_4h_to_h.bias
# 1034.4497 gpt_neox.layers.23.input_layernorm.weight
# -0.0956 gpt_neox.layers.23.input_layernorm.bias
# 1066.4004 gpt_neox.layers.23.post_attention_layernorm.weight
# -0.0286 gpt_neox.layers.23.post_attention_layernorm.bias
# 1.4622 gpt_neox.layers.23.attention.rotary_emb.inv_freq
# -7.5879 gpt_neox.layers.23.attention.query_key_value.weight
# -2.6558 gpt_neox.layers.23.attention.query_key_value.bias
# 2.8061 gpt_neox.layers.23.attention.dense.weight
# -0.0360 gpt_neox.layers.23.attention.dense.bias
# 106.9476 gpt_neox.layers.23.mlp.dense_h_to_4h.weight
# -14.5475 gpt_neox.layers.23.mlp.dense_h_to_4h.bias
# -12.4136 gpt_neox.layers.23.mlp.dense_4h_to_h.weight
# -0.0360 gpt_neox.layers.23.mlp.dense_4h_to_h.bias
# 1438.9121 gpt_neox.final_layer_norm.weight
# -0.3945 gpt_neox.final_layer_norm.bias
# 2402.6113 embed_out.weight

# %% [markdown]
# # Generation

# %%
model.eval()
output_ids = model.generate(max_length=100, do_sample=True)
output_ids
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# tensor([[50256,   796,   796,   796,   796,   796,   352,   301,  4289,   796,
#            796,   796,   796,   796,   220,   198, 50256]], device='cuda:0')

# %%
tokenizer.decode(output_ids[0])
# Out:
# '<|endoftext|> = = = = = 1st century = = = = = \n<|endoftext|>'

# %% [markdown]
# # Loss

# %%
ds = datasets.load_dataset('wikitext', 'wikitext-103-raw-v1')
# Out:
# Found cached dataset wikitext (/home/johnny/.cache/huggingface/datasets/wikitext/wikitext-103-raw-v1/1.0.0/a241db52902eaf2c6aa732210bead40c090019a499ceb13bcbfa3f8ab646a126)
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
acc, n, tokens, words = 0, 0, 0, 0
cutoff = 2000
pbar = tqdm(ds['test'].select(range(0, cutoff)), total=cutoff)
for i in pbar:
    sentence = i['text']
    if sentence == '':
        continue
    
    words += len(sentence.split(' ')) 
    input_ids = tokenizer.encode(sentence, return_tensors='pt').to(device)
    
    model.eval()
    output = model.forward(input_ids, labels=input_ids)
    
    n += 1
    tokens += len(input_ids[0])
    acc += output.loss.item()
    pbar.set_description(f'Avg loss: {acc/n:.2f}, Token ppl: {np.exp(acc / tokens):.2f}, Word ppl: {np.exp(acc / words):.2f}')
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]

# %% [markdown]
# # Accuracy

# %%
tokenizer.eos_token_id = 50256
tokenizer.pad_token_id = 50256
tokenizer.mask_token_id = 50256
tokenizer.decode([198])
# Out:
# '\n'

# %%
acc, n = 0, 0
pbar = tqdm(enumerate(ds['train']), total=len(ds['train']))
for i, example in pbar:
    sentence = example['text']
    if sentence == '':
        continue
    
    context = ''
    rollback = 5 - 1
    for j in range(i - rollback, i + 1):
        context += ds['train'][j]['text']
        
    input_ids = tokenizer.encode(context, return_tensors='pt').to(device)
    
    cutoff = len(input_ids[0]) - 2
    if len(input_ids[0]) <= cutoff+1:
        continue
    
    model.eval()
    output_ids = model.generate(input_ids[:,:cutoff], max_length=cutoff+1, \
                                do_sample=False, pad_token_id=tokenizer.eos_token_id)
    
    n += 1
    acc += 1 if output_ids[0,cutoff].item() == input_ids[0,cutoff].item() else 0
    
    pbar.set_description(f'Accuracy: {acc/n:.4f}')
# Out:
#   0%|          | 0/1801350 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [35], line 20
#      17     continue
#      19 model.eval()
# ---> 20 output_ids = model.generate(input_ids[:,:cutoff], max_length=cutoff+1, \
#      21                             do_sample=False, pad_token_id=tokenizer.eos_token_id)
#      23 n += 1
#      24 acc += 1 if output_ids[0,cutoff].item() == input_ids[0,cutoff].item() else 0
#
# File ~/.conda/envs/torch/lib/python3.8/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/.conda/envs/torch/lib/python3.8/site-packages/transformers/generation/utils.py:1538, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, **kwargs)
#    1532         raise ValueError(
#    1533             "num_return_sequences has to be 1 when doing greedy search, "
#    1534             f"but is {generation_config.num_return_sequences}."
#    1535         )
#    1537     # 11. run greedy search
# -> 1538     return self.greedy_search(
#    1539         input_ids,
#    1540         logits_processor=logits_processor,
#    1541         stopping_criteria=stopping_criteria,
#    1542         pad_token_id=generation_config.pad_token_id,
#    1543         eos_token_id=generation_config.eos_token_id,
#    1544         output_scores=generation_config.output_scores,
#    1545         return_dict_in_generate=generation_config.return_dict_in_generate,
#    1546         synced_gpus=synced_gpus,
#    1547         streamer=streamer,
#    1548         **model_kwargs,
#    1549     )
#    1551 elif is_contrastive_search_gen_mode:
#    1552     if generation_config.num_return_sequences > 1:
#
# File ~/.conda/envs/torch/lib/python3.8/site-packages/transformers/generation/utils.py:2362, in GenerationMixin.greedy_search(self, input_ids, logits_processor, stopping_criteria, max_length, pad_token_id, eos_token_id, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, synced_gpus, streamer, **model_kwargs)
#    2359 model_inputs = self.prepare_inputs_for_generation(input_ids, **model_kwargs)
#    2361 # forward pass to get next token
# -> 2362 outputs = self(
#    2363     **model_inputs,
#    2364     return_dict=True,
#    2365     output_attentions=output_attentions,
#    2366     output_hidden_states=output_hidden_states,
#    2367 )
#    2369 if synced_gpus and this_peer_finished:
#    2370     continue  # don't waste resources running the code we don't need
#
# File ~/.conda/envs/torch/lib/python3.8/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.conda/envs/torch/lib/python3.8/site-packages/transformers/models/gpt_neox/modeling_gpt_neox.py:766, in GPTNeoXForCausalLM.forward(self, input_ids, attention_mask, position_ids, inputs_embeds, head_mask, past_key_values, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#     725 r"""
#     726 past_key_values (`tuple(tuple(torch.FloatTensor))`, *optional*, returned when `use_cache=True` is passed or when `config.use_cache=True`):
#     727     Tuple of `tuple(torch.FloatTensor)` of length `config.n_layers`, with each tuple having 2 tensors of shape
#    (...)
#     762 >>> prediction_logits = outputs.logits
#     763 ```"""
#     764 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# --> 766 outputs = self.gpt_neox(
#     767     input_ids,
#     768     attention_mask=attention_mask,
#     769     position_ids=position_ids,
#     770     head_mask=head_mask,
#     771     inputs_embeds=inputs_embeds,
#     772     past_key_values=past_key_values,
#     773     use_cache=use_cache,
#     774     output_attentions=output_attentions,
#     775     output_hidden_states=output_hidden_states,
#     776     return_dict=return_dict,
#     777 )
#     779 hidden_states = outputs[0]
#     780 lm_logits = self.embed_out(hidden_states)
#
# File ~/.conda/envs/torch/lib/python3.8/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.conda/envs/torch/lib/python3.8/site-packages/transformers/models/gpt_neox/modeling_gpt_neox.py:657, in GPTNeoXModel.forward(self, input_ids, attention_mask, position_ids, head_mask, inputs_embeds, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     649     outputs = torch.utils.checkpoint.checkpoint(
#     650         create_custom_forward(layer),
#     651         hidden_states,
#    (...)
#     654         head_mask[i],
#     655     )
#     656 else:
# --> 657     outputs = layer(
#     658         hidden_states,
#     659         attention_mask=attention_mask,
#     660         position_ids=position_ids,
#     661         head_mask=head_mask[i],
#     662         layer_past=layer_past,
#     663         use_cache=use_cache,
#     664         output_attentions=output_attentions,
#     665     )
#     666 hidden_states = outputs[0]
#     667 if use_cache is True:
#
# File ~/.conda/envs/torch/lib/python3.8/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.conda/envs/torch/lib/python3.8/site-packages/transformers/models/gpt_neox/modeling_gpt_neox.py:420, in GPTNeoXLayer.forward(self, hidden_states, attention_mask, position_ids, head_mask, use_cache, layer_past, output_attentions)
#     410 def forward(
#     411     self,
#     412     hidden_states: Optional[torch.FloatTensor],
#    (...)
#     418     output_attentions: Optional[bool] = False,
#     419 ):
# --> 420     attention_layer_outputs = self.attention(
#     421         self.input_layernorm(hidden_states),
#     422         attention_mask=attention_mask,
#     423         position_ids=position_ids,
#     424         layer_past=layer_past,
#     425         head_mask=head_mask,
#     426         use_cache=use_cache,
#     427         output_attentions=output_attentions,
#     428     )
#     429     attn_output = attention_layer_outputs[0]  # output_attn: attn_output, present, (attn_weights)
#     430     attn_output = self.post_attention_dropout(attn_output)
#
# File ~/.conda/envs/torch/lib/python3.8/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.conda/envs/torch/lib/python3.8/site-packages/transformers/models/gpt_neox/modeling_gpt_neox.py:199, in GPTNeoXAttention.forward(self, hidden_states, attention_mask, position_ids, head_mask, layer_past, use_cache, output_attentions)
#     196 present = (key, value) if use_cache else None
#     198 # Compute attention
# --> 199 attn_output, attn_weights = self._attn(query, key, value, attention_mask, head_mask)
#     201 # Reshape outputs
#     202 attn_output = self._merge_heads(attn_output, self.num_attention_heads, self.head_size)
#
# File ~/.conda/envs/torch/lib/python3.8/site-packages/transformers/models/gpt_neox/modeling_gpt_neox.py:261, in GPTNeoXAttention._attn(self, query, key, value, attention_mask, head_mask)
#     248 key = key.view(batch_size * num_attention_heads, key_length, attn_head_size)
#     249 attn_scores = torch.zeros(
#     250     batch_size * num_attention_heads,
#     251     query_length,
#    (...)
#     254     device=key.device,
#     255 )
#     256 attn_scores = torch.baddbmm(
#     257     attn_scores,
#     258     query,
#     259     key.transpose(1, 2),
#     260     beta=1.0,
# --> 261     alpha=(torch.tensor(1.0, dtype=self.norm_factor.dtype, device=self.norm_factor.device) / self.norm_factor),
#     262 )
#     263 attn_scores = attn_scores.view(batch_size, num_attention_heads, query_length, key_length)
#     265 mask_value = torch.finfo(attn_scores.dtype).min
#
# KeyboardInterrupt:
